# %% [markdown]
# # Implémentez un modèle de scoring
# ## Phase 1.3 : Nettoyage des données
#
# Notebook utilisé pour le nettoyage https://www.kaggle.com/willkoehrsen/introduction-to-feature-selection

# %% [markdown]
# Standard imports for data science work. The LightGBM library is used for the gradient boosting machine.

# %%
# pandas and numpy for data manipulation
import pandas as pd
import numpy as np

# featuretools for automated feature engineering
import featuretools as ft

# matplotlit and seaborn for visualizations
import matplotlib.pyplot as plt
plt.rcParams['font.size'] = 22
import seaborn as sns

# Suppress warnings from pandas
import warnings
warnings.filterwarnings('ignore')

# modeling 
import lightgbm as lgb

# utilities
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder

# memory management
import gc

# %% [markdown]
# * `train_bureau` is the training features built manually using the `bureau` and `bureau_balance` data
# * `train_previous` is the training features built manually using the `previous`, `cash`, `credit`, and `installments` data
#
# We first will see how many features we built over the manual engineering process. Here we use a couple of set operations to find the columns that are only in the `bureau`, only in the `previous`, and in both dataframes, indicating that there are `original` features from the `application` dataframe. Here we are working with a small subset of the data in order to not overwhelm the kernel. This code has also been run on the full dataset (we will take a look at some of the results).

# %%
# Read in data
train_bureau = pd.read_feather('../../output/train_bureau_raw.ft')
test_bureau = pd.read_feather('../../output/test_bureau_raw.ft')

train_previous = pd.read_feather('../../output/train_previous_raw.ft')
test_previous = pd.read_feather('../../output/test_previous_raw.ft')

# All columns in dataframes
bureau_columns = list(train_bureau.columns)
previous_columns = list(train_previous.columns)

# %%
# Bureau only features
bureau_features = list(set(bureau_columns) - set(previous_columns))

# Previous only features
previous_features = list(set(previous_columns) - set(bureau_columns))

# Original features will be in both datasets
original_features = list(set(previous_columns) & set(bureau_columns))

print('There are %d original features.' % len(original_features))
print('There are %d bureau and bureau balance features.' % len(bureau_features))
print('There are %d previous Home Credit loan features.' % len(previous_features))
# Out:
# There are 122 original features.
# There are 211 bureau and bureau balance features.
# There are 1011 previous Home Credit loan features.

# %% [markdown]
# That gives us the number of features in each dataframe. Now we want to combine the data without creating any duplicate rows.

# %%
previous_features.append('SK_ID_CURR')

train_ids = train_bureau['SK_ID_CURR']
test_ids = test_bureau['SK_ID_CURR']

# Merge the dataframes avoiding duplicating columns by subsetting train_previous
train = train_bureau.merge(train_previous[previous_features], on = 'SK_ID_CURR')
test = test_bureau.merge(test_previous[previous_features], on = 'SK_ID_CURR')

print('Training shape: ', train.shape)
print('Testing shape: ', test.shape)
# Out:
# Training shape:  (307511, 1344)
# Testing shape:  (48744, 1343)

# %%
train_labels = train_bureau['TARGET']

# %% [markdown]
# Next we want to one-hot encode the dataframes. This doesn't give the full features since we are only working with a sample of the data and this will not create as many columns as one-hot encoding the entire dataset would. Doing this to the full dataset results in 1465 features.
#
# An important note in the code cell is where we __align the dataframes by the columns.__ This ensures we have the same columns in the training and testing datasets.

# %%
gc.enable()
del train_bureau, test_bureau, train_previous, test_previous
gc.collect()
# Out:
# 78

# %%
# One hot encoding
train = pd.get_dummies(train)
test = pd.get_dummies(test)

# Match the columns in the dataframes
train, test = train.align(test, join = 'inner', axis = 1)
print('Training shape: ', train.shape)
print('Testing shape: ', test.shape)
# Out:
# Training shape:  (307511, 1464)
# Testing shape:  (48744, 1464)

# %% [markdown]
# When we do this to the full dataset, we get __1465__ features.

# %% [markdown]
# # Remove Collinear Variables
#
# Collinear variables are those which are highly correlated with one another. These can decrease the model's availablility to learn, decrease model interpretability, and decrease generalization performance on the test set. Clearly, these are three things we want to increase, so removing collinear variables is a useful step. We will establish an admittedly arbitrary threshold for removing collinear variables, and then remove one out of any pair of variables that is above that threshold.
#
# The code below identifies the highly correlated variables based on the absolute magnitude of the Pearson correlation coefficient being greater than 0.9. Again, this is not entirely accurate since we are dealing with such a limited section of the data. This code is for illustration purposes, but if we read in the entire dataset, it would work (if the kernels allowed it)!
#
# This code is adapted from [work by Chris Albon](https://chrisalbon.com/machine_learning/feature_selection/drop_highly_correlated_features/).

# %% [markdown]
# ### Identify Correlated Variables

# %%
# Threshold for removing correlated variables
threshold = 0.9

# Absolute value correlation matrix
corr_matrix = train.corr().abs()
corr_matrix.head()
# Out:
#                   SK_ID_CURR  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# SK_ID_CURR          1.000000      0.001129          0.001820    0.000343
# CNT_CHILDREN        0.001129      1.000000          0.012882    0.002145
# AMT_INCOME_TOTAL    0.001820      0.012882          1.000000    0.156870
# AMT_CREDIT          0.000343      0.002145          0.156870    1.000000
# AMT_ANNUITY         0.000433      0.021374          0.191657    0.770138
#
#                   AMT_ANNUITY  AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE  \
# SK_ID_CURR           0.000433         0.000232                    0.000849
# CNT_CHILDREN         0.021374         0.001827                    0.025573
# AMT_INCOME_TOTAL     0.191657         0.159610                    0.074796
# AMT_CREDIT           0.770138         0.986968                    0.099738
# AMT_ANNUITY          1.000000         0.775109                    0.118429
#
#                   DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  ...  \
# SK_ID_CURR          0.001500       0.001366           0.000973  ...
# CNT_CHILDREN        0.330938       0.239818           0.183395  ...
# AMT_INCOME_TOTAL    0.027261       0.064223           0.027805  ...
# AMT_CREDIT          0.055436       0.066838           0.009621  ...
# AMT_ANNUITY         0.009445       0.104332           0.038514  ...
#
#                   HOUSETYPE_MODE_terraced house  WALLSMATERIAL_MODE_Block  \
# SK_ID_CURR                             0.000553                  0.002073
# CNT_CHILDREN                           0.001830                  0.005272
# AMT_INCOME_TOTAL                       0.000718                  0.011696
# AMT_CREDIT                             0.000869                  0.014314
# AMT_ANNUITY                            0.002166                  0.015589
#
#                   WALLSMATERIAL_MODE_Mixed  WALLSMATERIAL_MODE_Monolithic  \
# SK_ID_CURR                        0.000976                       0.000072
# CNT_CHILDREN                      0.000709                       0.001607
# AMT_INCOME_TOTAL                  0.006149                       0.023886
# AMT_CREDIT                        0.007987                       0.027255
# AMT_ANNUITY                       0.010077                       0.035318
#
#                   WALLSMATERIAL_MODE_Others  WALLSMATERIAL_MODE_Panel  \
# SK_ID_CURR                         0.001396                  0.002300
# CNT_CHILDREN                       0.002032                  0.020892
# AMT_INCOME_TOTAL                   0.003886                  0.032753
# AMT_CREDIT                         0.005799                  0.046644
# AMT_ANNUITY                        0.005968                  0.054988
#
#                   WALLSMATERIAL_MODE_Stone, brick  WALLSMATERIAL_MODE_Wooden  \
# SK_ID_CURR                               0.001281                   0.000270
# CNT_CHILDREN                             0.025088                   0.011036
# AMT_INCOME_TOTAL                         0.016523                   0.003369
# AMT_CREDIT                               0.009756                   0.007373
# AMT_ANNUITY                              0.009189                   0.007711
#
#                   EMERGENCYSTATE_MODE_No  EMERGENCYSTATE_MODE_Yes
# SK_ID_CURR                      0.000510                 0.002549
# CNT_CHILDREN                    0.038644                 0.004525
# AMT_INCOME_TOTAL                0.050174                 0.002894
# AMT_CREDIT                      0.058256                 0.004308
# AMT_ANNUITY                     0.068145                 0.003910
#
# [5 rows x 1464 columns]

# %%
# Upper triangle of correlations
upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
upper.head()
# Out:
#                   SK_ID_CURR  CNT_CHILDREN  AMT_INCOME_TOTAL  AMT_CREDIT  \
# SK_ID_CURR               NaN      0.001129          0.001820    0.000343
# CNT_CHILDREN             NaN           NaN          0.012882    0.002145
# AMT_INCOME_TOTAL         NaN           NaN               NaN    0.156870
# AMT_CREDIT               NaN           NaN               NaN         NaN
# AMT_ANNUITY              NaN           NaN               NaN         NaN
#
#                   AMT_ANNUITY  AMT_GOODS_PRICE  REGION_POPULATION_RELATIVE  \
# SK_ID_CURR           0.000433         0.000232                    0.000849
# CNT_CHILDREN         0.021374         0.001827                    0.025573
# AMT_INCOME_TOTAL     0.191657         0.159610                    0.074796
# AMT_CREDIT           0.770138         0.986968                    0.099738
# AMT_ANNUITY               NaN         0.775109                    0.118429
#
#                   DAYS_BIRTH  DAYS_EMPLOYED  DAYS_REGISTRATION  ...  \
# SK_ID_CURR          0.001500       0.001366           0.000973  ...
# CNT_CHILDREN        0.330938       0.239818           0.183395  ...
# AMT_INCOME_TOTAL    0.027261       0.064223           0.027805  ...
# AMT_CREDIT          0.055436       0.066838           0.009621  ...
# AMT_ANNUITY         0.009445       0.104332           0.038514  ...
#
#                   HOUSETYPE_MODE_terraced house  WALLSMATERIAL_MODE_Block  \
# SK_ID_CURR                             0.000553                  0.002073
# CNT_CHILDREN                           0.001830                  0.005272
# AMT_INCOME_TOTAL                       0.000718                  0.011696
# AMT_CREDIT                             0.000869                  0.014314
# AMT_ANNUITY                            0.002166                  0.015589
#
#                   WALLSMATERIAL_MODE_Mixed  WALLSMATERIAL_MODE_Monolithic  \
# SK_ID_CURR                        0.000976                       0.000072
# CNT_CHILDREN                      0.000709                       0.001607
# AMT_INCOME_TOTAL                  0.006149                       0.023886
# AMT_CREDIT                        0.007987                       0.027255
# AMT_ANNUITY                       0.010077                       0.035318
#
#                   WALLSMATERIAL_MODE_Others  WALLSMATERIAL_MODE_Panel  \
# SK_ID_CURR                         0.001396                  0.002300
# CNT_CHILDREN                       0.002032                  0.020892
# AMT_INCOME_TOTAL                   0.003886                  0.032753
# AMT_CREDIT                         0.005799                  0.046644
# AMT_ANNUITY                        0.005968                  0.054988
#
#                   WALLSMATERIAL_MODE_Stone, brick  WALLSMATERIAL_MODE_Wooden  \
# SK_ID_CURR                               0.001281                   0.000270
# CNT_CHILDREN                             0.025088                   0.011036
# AMT_INCOME_TOTAL                         0.016523                   0.003369
# AMT_CREDIT                               0.009756                   0.007373
# AMT_ANNUITY                              0.009189                   0.007711
#
#                   EMERGENCYSTATE_MODE_No  EMERGENCYSTATE_MODE_Yes
# SK_ID_CURR                      0.000510                 0.002549
# CNT_CHILDREN                    0.038644                 0.004525
# AMT_INCOME_TOTAL                0.050174                 0.002894
# AMT_CREDIT                      0.058256                 0.004308
# AMT_ANNUITY                     0.068145                 0.003910
#
# [5 rows x 1464 columns]

# %%
# Select columns with correlations above threshold
to_drop = [column for column in upper.columns if any(upper[column] > threshold)]

print('There are %d columns to remove.' % (len(to_drop)))
# Out:
# There are 610 columns to remove.

# %% [markdown]
# #### Drop Correlated Variables

# %%
train = train.drop(columns = to_drop)
test = test.drop(columns = to_drop)

print('Training shape: ', train.shape)
print('Testing shape: ', test.shape)
# Out:
# Training shape:  (307511, 854)
# Testing shape:  (48744, 854)

# %%
gc.enable()
del upper, corr_matrix
gc.collect()
# Out:
# 40

# %% [markdown]
# Applying this on the entire dataset __results in 538  collinear features__ removed.
#
# This has reduced the number of features singificantly, but it is likely still too many. At this point, we'll read in the full dataset after removing correlated variables for further feature selection.
#
# The full datasets (after removing correlated variables) are available in `m_train_combined.csv` and `m_test_combined.csv`.

# %% [markdown]
# ### Read in Full Dataset
#
# Now we are ready to move on to the full set of features. These were built by applying the above steps to the entire `train_bureau` and `train_previous` files (you can do the same if you want and have the computational resources)!

# %%
if not('TARGET' in train.columns):
    train['TARGET'] = train_labels
print('Training set full shape: ', train.shape)
print('Testing set full shape: ' , test.shape)
# Out:
# Training set full shape:  (307511, 855)
# Testing set full shape:  (48744, 854)

# %% [markdown]
# # Remove Missing Values
#
# A relatively simple choice of feature selection is removing missing values. Well, it seems simple, at least until we have to decide what percentage of missing values is the minimum threshold for removing a column. Like many choices in machine learning, there is no right answer, and not even a general rule of thumb for making this choice. In this implementation, if any columns have greater than 75% missing values, they will be removed.
#
# Most models (including those in Sk-Learn) cannot handle missing values, so we will have to fill these in before machine learning. The Gradient Boosting Machine ([at least in LightGBM](https://github.com/Microsoft/LightGBM/blob/master/docs/Advanced-Topics.rst)) can handle missing values. Imputing missing values always makes me a little uncomfortable because we are adding information that actually isn't in the dataset. Since we are going to be evaluating several models (in a later notebook), we will have to use some form of imputation. For now, we will focus on removing columns above the threshold.

# %%
# Train missing values (in percent)
train_missing = (train.isnull().sum() / len(train)).sort_values(ascending = False)
train_missing.head()
# Out:
# client_credit_AMT_PAYMENT_CURRENT_max_max             0.801438
# client_credit_AMT_PAYMENT_CURRENT_min_mean            0.801438
# client_credit_AMT_PAYMENT_CURRENT_mean_min            0.801438
# client_credit_AMT_DRAWINGS_OTHER_CURRENT_mean_mean    0.801178
# client_credit_CNT_DRAWINGS_ATM_CURRENT_mean_max       0.801178
# dtype: float64

# %%
# Test missing values (in percent)
test_missing = (test.isnull().sum() / len(test)).sort_values(ascending = False)
test_missing.head()
# Out:
# client_credit_AMT_DRAWINGS_OTHER_CURRENT_min_max    0.773223
# client_credit_AMT_DRAWINGS_ATM_CURRENT_mean_mean    0.773223
# client_credit_CNT_DRAWINGS_ATM_CURRENT_min_min      0.773223
# client_credit_AMT_DRAWINGS_POS_CURRENT_mean_min     0.773223
# client_credit_AMT_DRAWINGS_ATM_CURRENT_max_min      0.773223
# dtype: float64

# %%
# Identify missing values above threshold
train_missing = train_missing.index[train_missing > 0.75]
test_missing = test_missing.index[test_missing > 0.75]

all_missing = list(set(set(train_missing) | set(test_missing)))
print('There are %d columns with more than 75%% missing values' % len(all_missing))
# Out:
# There are 18 columns with more than 75% missing values

# %% [markdown]
# Let's drop the columns, one-hot encode the dataframes, and then align the columns of the dataframes.

# %%
# Need to save the labels because aligning will remove this column
train_labels = train["TARGET"]
train_ids = train['SK_ID_CURR']
test_ids = test['SK_ID_CURR']

train = pd.get_dummies(train.drop(columns = all_missing))
test = pd.get_dummies(test.drop(columns = all_missing))

train, test = train.align(test, join = 'inner', axis = 1)

print('Training set full shape: ', train.shape)
print('Testing set full shape: ' , test.shape)
# Out:
# Training set full shape:  (307511, 836)
# Testing set full shape:  (48744, 836)

# %%
train = train.drop(columns = ['SK_ID_CURR'])
test = test.drop(columns = ['SK_ID_CURR'])

# %% [markdown]
# # Feature Selection through Feature Importances
#
# The next method we can employ for feature selection is to use the feature importances of a model. Tree-based models (and consequently ensembles of trees) can determine an "importance" for each feature by measuring the reduction in impurity for including the feature in the model. I'm not really sure what that means (any explanations would be welcome) and the absolute value of the importance can be difficult to interpret. However, the relative value of the importances can be used as an approximation of the "relevance" of different features in a model. Moreover, we can use the feature importances to remove features that the model does not consider important.
#
# One method for doing this automatically is the [Recursive Feature Elimination method](http://scikit-learn.org/stable/modules/generated/sklearn.feature_selection.RFE.html) in Scikit-Learn. This accepts an estimator (one that either returns feature weights such as a linear regression, or feature importances such as a random forest) and a desired number of features. In then fits the model repeatedly on the data and iteratively removes the lowest importance features until the desired number of features is left. This means we have another arbitrary hyperparameter to use in out pipeline: the number of features to keep!
#
# Instead of doing this automatically, we can perform our own feature removal by first removing all zero importance features from the model. If this leaves too many features, then we can consider removing the features with the lowest importance. We will use a Gradient Boosted Model from the LightGBM library to assess feature importances. If you're used to the Scikit-Learn library, the LightGBM library has an API that makes deploying the model very similar to using a Scikit-Learn model.

# %% [markdown]
# Since the LightGBM model does not need missing values to be imputed, we can directly `fit` on the training data. We will use Early Stopping to determine the optimal number of iterations and run the model twice, averaging the feature importances to try and avoid overfitting to a certain set of features.

# %%
# Initialize an empty array to hold feature importances
feature_importances = np.zeros(train.shape[1])

# Create the model with several hyperparameters
model = lgb.LGBMClassifier(objective='binary', boosting_type = 'goss', n_estimators = 10000, class_weight = 'balanced')

# %%
for col in train.columns:
    print(col)
# Out:
# CNT_CHILDREN
# AMT_INCOME_TOTAL
# AMT_CREDIT
# AMT_ANNUITY
# REGION_POPULATION_RELATIVE
# DAYS_BIRTH
# DAYS_EMPLOYED
# DAYS_REGISTRATION
# DAYS_ID_PUBLISH
# OWN_CAR_AGE
# FLAG_MOBIL
# FLAG_WORK_PHONE
# FLAG_CONT_MOBILE
# FLAG_PHONE
# FLAG_EMAIL
# CNT_FAM_MEMBERS
# REGION_RATING_CLIENT
# HOUR_APPR_PROCESS_START
# REG_REGION_NOT_LIVE_REGION
# REG_REGION_NOT_WORK_REGION
# LIVE_REGION_NOT_WORK_REGION
# REG_CITY_NOT_LIVE_CITY
# REG_CITY_NOT_WORK_CITY
# LIVE_CITY_NOT_WORK_CITY
# EXT_SOURCE_1
# EXT_SOURCE_2
# EXT_SOURCE_3
# APARTMENTS_AVG
# BASEMENTAREA_AVG
# YEARS_BEGINEXPLUATATION_AVG
# YEARS_BUILD_AVG
# COMMONAREA_AVG
# ELEVATORS_AVG
# ENTRANCES_AVG
# FLOORSMAX_AVG
# FLOORSMIN_AVG
# LANDAREA_AVG
# NONLIVINGAPARTMENTS_AVG
# NONLIVINGAREA_AVG
# OBS_30_CNT_SOCIAL_CIRCLE
# DEF_30_CNT_SOCIAL_CIRCLE
# DEF_60_CNT_SOCIAL_CIRCLE
# DAYS_LAST_PHONE_CHANGE
# FLAG_DOCUMENT_2
# FLAG_DOCUMENT_3
# FLAG_DOCUMENT_4
# FLAG_DOCUMENT_5
# FLAG_DOCUMENT_6
# FLAG_DOCUMENT_7
# FLAG_DOCUMENT_8
# FLAG_DOCUMENT_9
# FLAG_DOCUMENT_10
# FLAG_DOCUMENT_11
# FLAG_DOCUMENT_12
# FLAG_DOCUMENT_13
# FLAG_DOCUMENT_14
# FLAG_DOCUMENT_15
# FLAG_DOCUMENT_16
# FLAG_DOCUMENT_17
# FLAG_DOCUMENT_18
# FLAG_DOCUMENT_19
# FLAG_DOCUMENT_20
# FLAG_DOCUMENT_21
# AMT_REQ_CREDIT_BUREAU_HOUR
# AMT_REQ_CREDIT_BUREAU_DAY
# AMT_REQ_CREDIT_BUREAU_WEEK
# AMT_REQ_CREDIT_BUREAU_MON
# AMT_REQ_CREDIT_BUREAU_QRT
# AMT_REQ_CREDIT_BUREAU_YEAR
# bureau_CREDIT_ACTIVE_Active_count
# bureau_CREDIT_ACTIVE_Active_count_norm
# bureau_CREDIT_ACTIVE_Bad debt_count
# bureau_CREDIT_ACTIVE_Bad debt_count_norm
# bureau_CREDIT_ACTIVE_Closed_count
# bureau_CREDIT_ACTIVE_Sold_count
# bureau_CREDIT_ACTIVE_Sold_count_norm
# bureau_CREDIT_CURRENCY_currency 1_count_norm
# bureau_CREDIT_CURRENCY_currency 2_count
# bureau_CREDIT_CURRENCY_currency 3_count
# bureau_CREDIT_CURRENCY_currency 3_count_norm
# bureau_CREDIT_CURRENCY_currency 4_count
# bureau_CREDIT_CURRENCY_currency 4_count_norm
# bureau_CREDIT_TYPE_Another type of loan_count
# bureau_CREDIT_TYPE_Another type of loan_count_norm
# bureau_CREDIT_TYPE_Car loan_count
# bureau_CREDIT_TYPE_Car loan_count_norm
# bureau_CREDIT_TYPE_Cash loan (non-earmarked)_count
# bureau_CREDIT_TYPE_Cash loan (non-earmarked)_count_norm
# bureau_CREDIT_TYPE_Consumer credit_count_norm
# bureau_CREDIT_TYPE_Credit card_count
# bureau_CREDIT_TYPE_Credit card_count_norm
# bureau_CREDIT_TYPE_Interbank credit_count
# bureau_CREDIT_TYPE_Loan for business development_count
# bureau_CREDIT_TYPE_Loan for business development_count_norm
# bureau_CREDIT_TYPE_Loan for purchase of shares (margin lending)_count
# bureau_CREDIT_TYPE_Loan for purchase of shares (margin lending)_count_norm
# bureau_CREDIT_TYPE_Loan for the purchase of equipment_count
# bureau_CREDIT_TYPE_Loan for the purchase of equipment_count_norm
# bureau_CREDIT_TYPE_Loan for working capital replenishment_count
# bureau_CREDIT_TYPE_Loan for working capital replenishment_count_norm
# bureau_CREDIT_TYPE_Microloan_count
# bureau_CREDIT_TYPE_Microloan_count_norm
# bureau_CREDIT_TYPE_Mobile operator loan_count
# bureau_CREDIT_TYPE_Mortgage_count
# bureau_CREDIT_TYPE_Mortgage_count_norm
# bureau_CREDIT_TYPE_Real estate loan_count
# bureau_CREDIT_TYPE_Real estate loan_count_norm
# bureau_CREDIT_TYPE_Unknown type of loan_count
# bureau_CREDIT_TYPE_Unknown type of loan_count_norm
# bureau_DAYS_CREDIT_mean
# bureau_DAYS_CREDIT_max
# bureau_DAYS_CREDIT_min
# bureau_DAYS_CREDIT_sum
# bureau_CREDIT_DAY_OVERDUE_mean
# bureau_CREDIT_DAY_OVERDUE_max
# bureau_CREDIT_DAY_OVERDUE_min
# bureau_DAYS_CREDIT_ENDDATE_mean
# bureau_DAYS_CREDIT_ENDDATE_max
# bureau_DAYS_CREDIT_ENDDATE_min
# bureau_DAYS_CREDIT_ENDDATE_sum
# bureau_DAYS_ENDDATE_FACT_mean
# bureau_DAYS_ENDDATE_FACT_max
# bureau_DAYS_ENDDATE_FACT_min
# bureau_AMT_CREDIT_MAX_OVERDUE_count
# bureau_AMT_CREDIT_MAX_OVERDUE_mean
# bureau_CNT_CREDIT_PROLONG_mean
# bureau_CNT_CREDIT_PROLONG_max
# bureau_CNT_CREDIT_PROLONG_min
# bureau_AMT_CREDIT_SUM_mean
# bureau_AMT_CREDIT_SUM_max
# bureau_AMT_CREDIT_SUM_min
# bureau_AMT_CREDIT_SUM_sum
# bureau_AMT_CREDIT_SUM_DEBT_mean
# bureau_AMT_CREDIT_SUM_DEBT_max
# bureau_AMT_CREDIT_SUM_DEBT_min
# bureau_AMT_CREDIT_SUM_LIMIT_mean
# bureau_AMT_CREDIT_SUM_LIMIT_max
# bureau_AMT_CREDIT_SUM_LIMIT_min
# bureau_AMT_CREDIT_SUM_OVERDUE_mean
# bureau_AMT_CREDIT_SUM_OVERDUE_max
# bureau_AMT_CREDIT_SUM_OVERDUE_min
# bureau_DAYS_CREDIT_UPDATE_mean
# bureau_DAYS_CREDIT_UPDATE_max
# bureau_DAYS_CREDIT_UPDATE_min
# bureau_AMT_ANNUITY_count
# bureau_AMT_ANNUITY_mean
# bureau_AMT_ANNUITY_max
# bureau_AMT_ANNUITY_min
# client_bureau_balance_MONTHS_BALANCE_count_mean
# client_bureau_balance_MONTHS_BALANCE_count_max
# client_bureau_balance_MONTHS_BALANCE_count_min
# client_bureau_balance_MONTHS_BALANCE_count_sum
# client_bureau_balance_MONTHS_BALANCE_mean_min
# client_bureau_balance_MONTHS_BALANCE_max_mean
# client_bureau_balance_MONTHS_BALANCE_max_max
# client_bureau_balance_MONTHS_BALANCE_max_min
# client_bureau_balance_MONTHS_BALANCE_max_sum
# client_bureau_balance_STATUS_0_count_mean
# client_bureau_balance_STATUS_0_count_max
# client_bureau_balance_STATUS_0_count_min
# client_bureau_balance_STATUS_0_count_sum
# client_bureau_balance_STATUS_0_count_norm_mean
# client_bureau_balance_STATUS_0_count_norm_max
# client_bureau_balance_STATUS_0_count_norm_min
# client_bureau_balance_STATUS_0_count_norm_sum
# client_bureau_balance_STATUS_1_count_mean
# client_bureau_balance_STATUS_1_count_max
# client_bureau_balance_STATUS_1_count_min
# client_bureau_balance_STATUS_1_count_sum
# client_bureau_balance_STATUS_1_count_norm_mean
# client_bureau_balance_STATUS_1_count_norm_max
# client_bureau_balance_STATUS_1_count_norm_min
# client_bureau_balance_STATUS_1_count_norm_sum
# client_bureau_balance_STATUS_2_count_mean
# client_bureau_balance_STATUS_2_count_max
# client_bureau_balance_STATUS_2_count_min
# client_bureau_balance_STATUS_2_count_sum
# client_bureau_balance_STATUS_2_count_norm_mean
# client_bureau_balance_STATUS_2_count_norm_max
# client_bureau_balance_STATUS_2_count_norm_min
# client_bureau_balance_STATUS_2_count_norm_sum
# client_bureau_balance_STATUS_3_count_mean
# client_bureau_balance_STATUS_3_count_max
# client_bureau_balance_STATUS_3_count_min
# client_bureau_balance_STATUS_3_count_sum
# client_bureau_balance_STATUS_3_count_norm_mean
# client_bureau_balance_STATUS_3_count_norm_max
# client_bureau_balance_STATUS_3_count_norm_min
# client_bureau_balance_STATUS_3_count_norm_sum
# client_bureau_balance_STATUS_4_count_mean
# client_bureau_balance_STATUS_4_count_max
# client_bureau_balance_STATUS_4_count_min
# client_bureau_balance_STATUS_4_count_sum
# client_bureau_balance_STATUS_4_count_norm_mean
# client_bureau_balance_STATUS_4_count_norm_max
# client_bureau_balance_STATUS_4_count_norm_min
# client_bureau_balance_STATUS_4_count_norm_sum
# client_bureau_balance_STATUS_5_count_mean
# client_bureau_balance_STATUS_5_count_max
# client_bureau_balance_STATUS_5_count_min
# client_bureau_balance_STATUS_5_count_sum
# client_bureau_balance_STATUS_5_count_norm_max
# client_bureau_balance_STATUS_5_count_norm_min
# client_bureau_balance_STATUS_5_count_norm_sum
# client_bureau_balance_STATUS_C_count_mean
# client_bureau_balance_STATUS_C_count_max
# client_bureau_balance_STATUS_C_count_min
# client_bureau_balance_STATUS_C_count_norm_mean
# client_bureau_balance_STATUS_C_count_norm_max
# client_bureau_balance_STATUS_C_count_norm_min
# client_bureau_balance_STATUS_X_count_mean
# client_bureau_balance_STATUS_X_count_max
# client_bureau_balance_STATUS_X_count_min
# client_bureau_balance_STATUS_X_count_sum
# client_bureau_balance_STATUS_X_count_norm_mean
# client_bureau_balance_STATUS_X_count_norm_max
# client_bureau_balance_STATUS_X_count_norm_min
# client_bureau_balance_STATUS_X_count_norm_sum
# client_credit_AMT_INST_MIN_REGULARITY_max_max
# previous_CHANNEL_TYPE_Credit and cash offices_mean
# client_installments_DAYS_ENTRY_PAYMENT_max_max
# previous_DAYS_DECISION_min
# previous_NAME_CONTRACT_TYPE_Cash loans_count
# client_credit_CNT_DRAWINGS_CURRENT_sum_mean
# previous_PRODUCT_COMBINATION_Cash Street: middle_sum
# client_credit_AMT_PAYMENT_TOTAL_CURRENT_max_sum
# client_cash_NAME_CONTRACT_STATUS_XNA_sum_max
# previous_DAYS_TERMINATION_mean
# previous_CHANNEL_TYPE_Channel of corporate sales_sum
# previous_NAME_CONTRACT_STATUS_Refused_sum
# previous_DAYS_FIRST_DUE_min
# previous_NAME_GOODS_CATEGORY_House Construction_mean
# client_cash_CNT_INSTALMENT_FUTURE_min_max
# client_cash_NAME_CONTRACT_STATUS_Completed_mean_max
# previous_NAME_GOODS_CATEGORY_Homewares_sum
# client_credit_CNT_DRAWINGS_OTHER_CURRENT_min_sum
# client_credit_NAME_CONTRACT_STATUS_Refused_mean_mean
# client_cash_NAME_CONTRACT_STATUS_Signed_sum_max
# client_installments_AMT_INSTALMENT_max_mean
# client_cash_NAME_CONTRACT_STATUS_Active_mean_mean
# previous_WEEKDAY_APPR_PROCESS_START_SATURDAY_mean
# client_credit_SK_DPD_DEF_max_sum
# client_credit_CNT_DRAWINGS_ATM_CURRENT_sum_min
# previous_NAME_SELLER_INDUSTRY_MLM partners_mean
# client_credit_AMT_RECEIVABLE_PRINCIPAL_min_sum
# previous_DAYS_FIRST_DRAWING_min
# client_cash_SK_DPD_DEF_max_min
# client_cash_NAME_CONTRACT_STATUS_Demand_sum_max
# client_cash_NAME_CONTRACT_STATUS_Approved_mean_min
# previous_NAME_GOODS_CATEGORY_Weapon_sum
# previous_AMT_ANNUITY_max
# previous_PRODUCT_COMBINATION_POS mobile without interest_sum
# client_cash_NAME_CONTRACT_STATUS_Canceled_mean_min
# client_cash_CNT_INSTALMENT_FUTURE_min_count
# client_credit_AMT_INST_MIN_REGULARITY_sum_min
# client_cash_NAME_CONTRACT_STATUS_Approved_mean_max
# client_credit_AMT_DRAWINGS_POS_CURRENT_mean_sum
# previous_PRODUCT_COMBINATION_Cash X-Sell: low_sum
# client_cash_NAME_CONTRACT_STATUS_Demand_mean_min
# client_cash_CNT_INSTALMENT_min_min
# client_installments_AMT_PAYMENT_min_mean
# previous_NAME_PRODUCT_TYPE_x-sell_mean
# client_cash_CNT_INSTALMENT_FUTURE_min_mean
# client_credit_AMT_DRAWINGS_CURRENT_max_max
# previous_PRODUCT_COMBINATION_POS household without interest_mean
# client_credit_AMT_TOTAL_RECEIVABLE_min_max
# client_cash_NAME_CONTRACT_STATUS_Returned to the store_sum_max
# client_installments_NUM_INSTALMENT_VERSION_count_max
# client_credit_CNT_DRAWINGS_CURRENT_min_sum
# previous_CODE_REJECT_REASON_SYSTEM_mean
# previous_NAME_CASH_LOAN_PURPOSE_Education_mean
# previous_NFLAG_INSURED_ON_APPROVAL_mean
# client_credit_NAME_CONTRACT_STATUS_Demand_sum_min
# client_credit_NAME_CONTRACT_STATUS_Sent proposal_sum_mean
# previous_NAME_TYPE_SUITE_Family_mean
# client_credit_CNT_INSTALMENT_MATURE_CUM_max_sum
# client_credit_MONTHS_BALANCE_max_mean
# client_cash_CNT_INSTALMENT_mean_max
# client_cash_CNT_INSTALMENT_count_mean
# client_credit_AMT_INST_MIN_REGULARITY_mean_min
# previous_NFLAG_INSURED_ON_APPROVAL_min
# previous_NAME_SELLER_INDUSTRY_Clothing_mean
# client_cash_NAME_CONTRACT_STATUS_Canceled_sum_mean
# previous_NAME_CASH_LOAN_PURPOSE_Buying a used car_mean
# previous_NAME_PRODUCT_TYPE_x-sell_sum
# client_cash_CNT_INSTALMENT_sum_min
# client_installments_AMT_INSTALMENT_mean_min
# client_credit_AMT_CREDIT_LIMIT_ACTUAL_sum_sum
# previous_NAME_CASH_LOAN_PURPOSE_Business development_mean
# previous_RATE_INTEREST_PRIMARY_sum
# previous_HOUR_APPR_PROCESS_START_min
# client_cash_NAME_CONTRACT_STATUS_Demand_mean_max
# previous_NAME_SELLER_INDUSTRY_Industry_mean
# client_credit_AMT_CREDIT_LIMIT_ACTUAL_max_max
# client_cash_NAME_CONTRACT_STATUS_Amortized debt_mean_sum
# client_cash_CNT_INSTALMENT_FUTURE_mean_sum
# previous_NAME_CASH_LOAN_PURPOSE_Payments on other loans_mean
# previous_NAME_CASH_LOAN_PURPOSE_Buying a home_sum
# previous_PRODUCT_COMBINATION_Cash X-Sell: high_sum
# previous_NAME_CASH_LOAN_PURPOSE_Refusal to name the goal_sum
# client_cash_CNT_INSTALMENT_mean_min
# client_credit_CNT_DRAWINGS_ATM_CURRENT_sum_sum
# client_credit_AMT_DRAWINGS_CURRENT_min_min
# client_credit_AMT_PAYMENT_TOTAL_CURRENT_mean_sum
# client_cash_NAME_CONTRACT_STATUS_Active_count_min
# client_cash_NAME_CONTRACT_STATUS_Active_sum_sum
# client_credit_AMT_DRAWINGS_CURRENT_mean_max
# client_credit_AMT_DRAWINGS_OTHER_CURRENT_mean_sum
# previous_NAME_CASH_LOAN_PURPOSE_XNA_sum
# client_credit_AMT_DRAWINGS_ATM_CURRENT_sum_mean
# client_cash_NAME_CONTRACT_STATUS_Canceled_mean_sum
# previous_CHANNEL_TYPE_Stone_sum
# previous_NAME_PRODUCT_TYPE_walk-in_mean
# previous_DAYS_LAST_DUE_1ST_VERSION_mean
# previous_AMT_ANNUITY_min
# previous_NAME_SELLER_INDUSTRY_Tourism_sum
# previous_RATE_DOWN_PAYMENT_mean
# previous_RATE_INTEREST_PRIVILEGED_sum
# previous_NAME_SELLER_INDUSTRY_Jewelry_sum
# previous_CHANNEL_TYPE_Contact center_mean
# client_cash_SK_DPD_mean_min
# client_installments_DAYS_INSTALMENT_max_sum
# previous_NAME_CONTRACT_TYPE_Consumer loans_mean
# client_credit_CNT_DRAWINGS_OTHER_CURRENT_sum_min
# client_credit_AMT_PAYMENT_TOTAL_CURRENT_sum_sum
# client_credit_NAME_CONTRACT_STATUS_Active_mean_mean
# previous_NAME_YIELD_GROUP_middle_mean
# previous_NAME_TYPE_SUITE_Unaccompanied_sum
# client_installments_AMT_PAYMENT_max_sum
# client_installments_NUM_INSTALMENT_NUMBER_sum_min
# client_credit_AMT_DRAWINGS_CURRENT_max_sum
# previous_NAME_SELLER_INDUSTRY_MLM partners_sum
# previous_CODE_REJECT_REASON_SCOFR_mean
# previous_DAYS_DECISION_max
# client_cash_SK_DPD_min_min
# previous_PRODUCT_COMBINATION_POS mobile with interest_mean
# previous_NAME_GOODS_CATEGORY_Additional Service_mean
# previous_CODE_REJECT_REASON_XNA_mean
# client_installments_NUM_INSTALMENT_NUMBER_min_min
# previous_PRODUCT_COMBINATION_Card Street_sum
# previous_NAME_CASH_LOAN_PURPOSE_Education_sum
# client_cash_SK_DPD_DEF_min_sum
# client_credit_SK_DPD_sum_min
# client_credit_AMT_BALANCE_max_sum
# client_cash_NAME_CONTRACT_STATUS_Completed_sum_sum
# client_cash_SK_DPD_min_sum
# previous_PRODUCT_COMBINATION_POS household with interest_mean
# previous_NAME_GOODS_CATEGORY_Audio/Video_mean
# previous_NAME_PRODUCT_TYPE_XNA_sum
# previous_DAYS_DECISION_mean
# previous_NAME_PAYMENT_TYPE_Non-cash from your account_sum
# previous_AMT_GOODS_PRICE_max
# client_credit_AMT_DRAWINGS_ATM_CURRENT_min_sum
# client_credit_CNT_DRAWINGS_POS_CURRENT_sum_sum
# previous_NAME_GOODS_CATEGORY_Auto Accessories_mean
# previous_NAME_PORTFOLIO_Cash_sum
# client_installments_DAYS_INSTALMENT_min_max
# client_installments_NUM_INSTALMENT_VERSION_sum_max
# previous_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_mean
# previous_NAME_PRODUCT_TYPE_walk-in_sum
# client_credit_NAME_CONTRACT_STATUS_Approved_mean_sum
# previous_NAME_GOODS_CATEGORY_Weapon_mean
# previous_DAYS_LAST_DUE_1ST_VERSION_sum
# previous_FLAG_LAST_APPL_PER_CONTRACT_N_mean
# client_cash_SK_DPD_mean_mean
# client_cash_SK_DPD_DEF_max_sum
# client_credit_AMT_CREDIT_LIMIT_ACTUAL_min_sum
# previous_DAYS_FIRST_DRAWING_sum
# client_installments_NUM_INSTALMENT_VERSION_mean_min
# previous_NAME_GOODS_CATEGORY_Vehicles_sum
# previous_SELLERPLACE_AREA_sum
# previous_NAME_CASH_LOAN_PURPOSE_Business development_sum
# client_credit_CNT_DRAWINGS_ATM_CURRENT_min_sum
# client_credit_CNT_DRAWINGS_CURRENT_max_max
# client_credit_AMT_PAYMENT_CURRENT_min_sum
# client_installments_DAYS_ENTRY_PAYMENT_max_mean
# previous_NAME_CASH_LOAN_PURPOSE_Buying a holiday home / land_sum
# client_cash_NAME_CONTRACT_STATUS_Completed_sum_min
# previous_PRODUCT_COMBINATION_Card Street_mean
# previous_AMT_DOWN_PAYMENT_sum
# previous_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_sum
# previous_NAME_CASH_LOAN_PURPOSE_Buying a garage_mean
# previous_PRODUCT_COMBINATION_Cash X-Sell: low_mean
# previous_NAME_CASH_LOAN_PURPOSE_Medicine_sum
# previous_CODE_REJECT_REASON_LIMIT_mean
# previous_NAME_GOODS_CATEGORY_Jewelry_sum
# previous_PRODUCT_COMBINATION_POS other with interest_sum
# client_credit_AMT_DRAWINGS_POS_CURRENT_min_sum
# previous_NFLAG_INSURED_ON_APPROVAL_max
# previous_PRODUCT_COMBINATION_Cash Street: middle_mean
# client_credit_NAME_CONTRACT_STATUS_Signed_mean_max
# previous_NAME_GOODS_CATEGORY_Construction Materials_sum
# previous_RATE_DOWN_PAYMENT_sum
# previous_CHANNEL_TYPE_Contact center_sum
# previous_CODE_REJECT_REASON_VERIF_mean
# client_credit_CNT_DRAWINGS_CURRENT_mean_mean
# previous_NAME_PORTFOLIO_Cars_sum
# previous_NAME_GOODS_CATEGORY_Mobile_sum
# previous_NAME_SELLER_INDUSTRY_Construction_mean
# client_cash_NAME_CONTRACT_STATUS_Amortized debt_sum_min
# client_cash_CNT_INSTALMENT_sum_mean
# previous_CODE_REJECT_REASON_SYSTEM_sum
# previous_DAYS_TERMINATION_sum
# previous_PRODUCT_COMBINATION_Cash Street: high_sum
# previous_PRODUCT_COMBINATION_POS other with interest_mean
# client_credit_AMT_DRAWINGS_POS_CURRENT_max_sum
# client_credit_AMT_CREDIT_LIMIT_ACTUAL_min_mean
# previous_NAME_GOODS_CATEGORY_Education_sum
# client_installments_AMT_PAYMENT_mean_max
# client_credit_AMT_CREDIT_LIMIT_ACTUAL_sum_min
# client_credit_CNT_DRAWINGS_CURRENT_max_sum
# previous_NAME_PORTFOLIO_XNA_sum
# client_installments_AMT_PAYMENT_min_min
# previous_NAME_CLIENT_TYPE_XNA_mean
# previous_NAME_TYPE_SUITE_Other_B_mean
# previous_NAME_CASH_LOAN_PURPOSE_Medicine_mean
# client_cash_CNT_INSTALMENT_min_max
# client_installments_NUM_INSTALMENT_VERSION_max_max
# previous_SELLERPLACE_AREA_mean
# previous_NAME_CASH_LOAN_PURPOSE_Payments on other loans_sum
# client_installments_DAYS_ENTRY_PAYMENT_count_min
# previous_NAME_CASH_LOAN_PURPOSE_Building a house or an annex_sum
# client_installments_AMT_INSTALMENT_sum_mean
# previous_CODE_REJECT_REASON_SCO_sum
# previous_NAME_SELLER_INDUSTRY_Furniture_mean
# client_cash_SK_DPD_max_min
# client_installments_AMT_PAYMENT_min_max
# previous_PRODUCT_COMBINATION_Cash X-Sell: middle_mean
# previous_NAME_SELLER_INDUSTRY_Auto technology_mean
# client_credit_CNT_DRAWINGS_CURRENT_min_mean
# client_installments_DAYS_ENTRY_PAYMENT_min_count
# client_credit_NAME_CONTRACT_STATUS_Completed_mean_sum
# previous_PRODUCT_COMBINATION_POS household with interest_sum
# previous_NAME_CASH_LOAN_PURPOSE_Buying a holiday home / land_mean
# client_credit_CNT_DRAWINGS_ATM_CURRENT_max_sum
# previous_AMT_ANNUITY_mean
# client_installments_NUM_INSTALMENT_NUMBER_min_mean
# previous_PRODUCT_COMBINATION_POS others without interest_sum
# client_credit_CNT_INSTALMENT_MATURE_CUM_min_min
# client_cash_NAME_CONTRACT_STATUS_Signed_mean_mean
# previous_NAME_CASH_LOAN_PURPOSE_Gasification / water supply_sum
# previous_DAYS_FIRST_DRAWING_max
# previous_NAME_GOODS_CATEGORY_Gardening_mean
# client_cash_NAME_CONTRACT_STATUS_Completed_mean_sum
# client_installments_AMT_INSTALMENT_mean_mean
# previous_CODE_REJECT_REASON_XAP_mean
# previous_CHANNEL_TYPE_AP+ (Cash loan)_mean
# previous_NAME_PORTFOLIO_XNA_mean
# previous_CODE_REJECT_REASON_XNA_sum
# client_installments_AMT_PAYMENT_sum_min
# client_credit_CNT_DRAWINGS_OTHER_CURRENT_max_sum
# previous_PRODUCT_COMBINATION_POS household without interest_sum
# previous_NAME_GOODS_CATEGORY_Animals_mean
# client_installments_AMT_PAYMENT_mean_sum
# client_cash_CNT_INSTALMENT_FUTURE_mean_mean
# previous_NAME_TYPE_SUITE_Unaccompanied_mean
# previous_CODE_REJECT_REASON_LIMIT_sum
# previous_AMT_ANNUITY_sum
# previous_NAME_TYPE_SUITE_Other_A_sum
# previous_NAME_SELLER_INDUSTRY_Industry_sum
# client_credit_NAME_CONTRACT_STATUS_Signed_sum_max
# previous_HOUR_APPR_PROCESS_START_max
# previous_WEEKDAY_APPR_PROCESS_START_MONDAY_mean
# previous_NAME_TYPE_SUITE_Children_sum
# previous_DAYS_LAST_DUE_max
# previous_PRODUCT_COMBINATION_Cash X-Sell: middle_sum
# previous_NAME_CASH_LOAN_PURPOSE_Buying a garage_sum
# previous_CHANNEL_TYPE_Car dealer_mean
# previous_PRODUCT_COMBINATION_POS others without interest_mean
# client_cash_SK_DPD_DEF_min_min
# previous_NAME_CONTRACT_STATUS_Canceled_mean
# client_installments_NUM_INSTALMENT_VERSION_max_mean
# previous_NAME_GOODS_CATEGORY_Construction Materials_mean
# previous_NAME_GOODS_CATEGORY_Clothing and Accessories_sum
# previous_WEEKDAY_APPR_PROCESS_START_TUESDAY_sum
# previous_NAME_GOODS_CATEGORY_Tourism_sum
# client_credit_AMT_RECIVABLE_sum_sum
# client_installments_AMT_PAYMENT_sum_max
# client_installments_NUM_INSTALMENT_VERSION_min_max
# previous_NAME_GOODS_CATEGORY_Medical Supplies_sum
# client_cash_NAME_CONTRACT_STATUS_Completed_mean_min
# client_installments_NUM_INSTALMENT_VERSION_sum_mean
# client_credit_CNT_DRAWINGS_POS_CURRENT_max_sum
# previous_NAME_CASH_LOAN_PURPOSE_Furniture_mean
# client_installments_NUM_INSTALMENT_NUMBER_max_max
# previous_PRODUCT_COMBINATION_Cash Street: low_mean
# previous_NAME_SELLER_INDUSTRY_Consumer electronics_sum
# previous_NAME_GOODS_CATEGORY_Additional Service_sum
# previous_PRODUCT_COMBINATION_POS industry without interest_mean
# previous_NAME_PORTFOLIO_Cash_mean
# previous_NAME_CASH_LOAN_PURPOSE_XAP_sum
# previous_NAME_GOODS_CATEGORY_Medicine_sum
# previous_NAME_YIELD_GROUP_high_mean
# client_cash_MONTHS_BALANCE_sum_max
# previous_NAME_CASH_LOAN_PURPOSE_Wedding / gift / holiday_mean
# client_credit_AMT_INST_MIN_REGULARITY_min_sum
# previous_NAME_SELLER_INDUSTRY_Auto technology_sum
# previous_NAME_CASH_LOAN_PURPOSE_Everyday expenses_mean
# previous_AMT_GOODS_PRICE_min
# client_credit_CNT_DRAWINGS_CURRENT_sum_sum
# previous_NAME_CASH_LOAN_PURPOSE_Other_sum
# previous_NAME_SELLER_INDUSTRY_Consumer electronics_mean
# previous_CODE_REJECT_REASON_VERIF_sum
# previous_NAME_TYPE_SUITE_Spouse, partner_sum
# previous_NAME_CONTRACT_TYPE_Revolving loans_mean
# client_credit_AMT_INST_MIN_REGULARITY_min_min
# previous_DAYS_FIRST_DUE_sum
# client_credit_CNT_DRAWINGS_OTHER_CURRENT_sum_sum
# previous_WEEKDAY_APPR_PROCESS_START_SATURDAY_sum
# previous_NAME_GOODS_CATEGORY_Fitness_sum
# previous_NAME_CLIENT_TYPE_New_mean
# previous_NAME_CASH_LOAN_PURPOSE_Repairs_mean
# previous_AMT_GOODS_PRICE_mean
# client_installments_AMT_INSTALMENT_min_sum
# previous_NAME_CASH_LOAN_PURPOSE_Hobby_mean
# previous_NAME_SELLER_INDUSTRY_Jewelry_mean
# client_cash_NAME_CONTRACT_STATUS_Active_mean_min
# previous_NAME_GOODS_CATEGORY_Office Appliances_sum
# previous_NAME_CONTRACT_STATUS_Unused offer_sum
# previous_CHANNEL_TYPE_Stone_mean
# client_cash_NAME_CONTRACT_STATUS_Signed_mean_min
# previous_NAME_CLIENT_TYPE_Refreshed_mean
# previous_DAYS_LAST_DUE_min
# previous_CHANNEL_TYPE_Country-wide_sum
# previous_AMT_DOWN_PAYMENT_count
# client_installments_NUM_INSTALMENT_VERSION_sum_min
# previous_WEEKDAY_APPR_PROCESS_START_THURSDAY_mean
# previous_NAME_TYPE_SUITE_Group of people_mean
# previous_DAYS_DECISION_sum
# previous_WEEKDAY_APPR_PROCESS_START_THURSDAY_sum
# client_credit_AMT_DRAWINGS_OTHER_CURRENT_sum_sum
# client_installments_NUM_INSTALMENT_NUMBER_max_min
# client_installments_AMT_INSTALMENT_max_max
# previous_WEEKDAY_APPR_PROCESS_START_FRIDAY_mean
# previous_NAME_GOODS_CATEGORY_Education_mean
# client_cash_NAME_CONTRACT_STATUS_Returned to the store_sum_min
# client_cash_NAME_CONTRACT_STATUS_Approved_sum_sum
# previous_PRODUCT_COMBINATION_Cash X-Sell: high_mean
# previous_NAME_TYPE_SUITE_Other_A_mean
# previous_NAME_CONTRACT_STATUS_Unused offer_mean
# previous_NAME_GOODS_CATEGORY_Jewelry_mean
# previous_NAME_GOODS_CATEGORY_Other_mean
# previous_CHANNEL_TYPE_Regional / Local_mean
# previous_NAME_CASH_LOAN_PURPOSE_Urgent needs_mean
# client_credit_MONTHS_BALANCE_max_sum
# previous_NAME_CASH_LOAN_PURPOSE_Other_mean
# previous_NAME_CLIENT_TYPE_Repeater_mean
# previous_NAME_YIELD_GROUP_middle_sum
# previous_CNT_PAYMENT_max
# previous_PRODUCT_COMBINATION_Cash_mean
# client_cash_CNT_INSTALMENT_FUTURE_min_sum
# client_cash_NAME_CONTRACT_STATUS_Approved_mean_sum
# previous_NAME_CASH_LOAN_PURPOSE_Hobby_sum
# previous_NAME_CASH_LOAN_PURPOSE_Refusal to name the goal_mean
# previous_NAME_GOODS_CATEGORY_House Construction_sum
# previous_NAME_GOODS_CATEGORY_Medicine_mean
# previous_NAME_CASH_LOAN_PURPOSE_Furniture_sum
# client_cash_NAME_CONTRACT_STATUS_XNA_mean_min
# previous_NAME_CLIENT_TYPE_New_sum
# client_cash_NAME_CONTRACT_STATUS_Demand_sum_min
# previous_NAME_GOODS_CATEGORY_Fitness_mean
# previous_AMT_CREDIT_min
# client_credit_AMT_DRAWINGS_ATM_CURRENT_sum_sum
# previous_NAME_CASH_LOAN_PURPOSE_Wedding / gift / holiday_sum
# previous_NAME_PAYMENT_TYPE_Cash through the bank_mean
# previous_NAME_GOODS_CATEGORY_Furniture_mean
# previous_HOUR_APPR_PROCESS_START_mean
# previous_NAME_GOODS_CATEGORY_Photo / Cinema Equipment_sum
# previous_NAME_CASH_LOAN_PURPOSE_Purchase of electronic equipment_sum
# client_cash_NAME_CONTRACT_STATUS_Completed_mean_mean
# previous_NAME_PAYMENT_TYPE_Cashless from the account of the employer_sum
# previous_PRODUCT_COMBINATION_POS mobile with interest_sum
# client_installments_AMT_INSTALMENT_sum_sum
# previous_PRODUCT_COMBINATION_POS industry without interest_sum
# previous_NAME_CASH_LOAN_PURPOSE_Everyday expenses_sum
# previous_NAME_CLIENT_TYPE_XNA_sum
# previous_NAME_CLIENT_TYPE_Refreshed_sum
# previous_NAME_YIELD_GROUP_low_action_mean
# previous_NAME_CONTRACT_TYPE_Cash loans_mean
# previous_WEEKDAY_APPR_PROCESS_START_TUESDAY_mean
# client_installments_NUM_INSTALMENT_VERSION_min_min
# previous_RATE_DOWN_PAYMENT_max
# previous_NAME_CASH_LOAN_PURPOSE_Money for a third person_mean
# previous_CNT_PAYMENT_mean
# client_installments_NUM_INSTALMENT_VERSION_sum_sum
# previous_NAME_GOODS_CATEGORY_Computers_sum
# client_installments_NUM_INSTALMENT_VERSION_max_sum
# previous_NAME_TYPE_SUITE_Children_mean
# previous_NAME_SELLER_INDUSTRY_Construction_sum
# client_credit_AMT_PAYMENT_TOTAL_CURRENT_min_sum
# previous_NAME_CASH_LOAN_PURPOSE_Urgent needs_sum
# previous_DAYS_FIRST_DRAWING_mean
# client_cash_NAME_CONTRACT_STATUS_Canceled_mean_max
# previous_NAME_GOODS_CATEGORY_Photo / Cinema Equipment_mean
# previous_NAME_CASH_LOAN_PURPOSE_Money for a third person_sum
# client_installments_DAYS_INSTALMENT_sum_max
# previous_NAME_GOODS_CATEGORY_Office Appliances_mean
# previous_NAME_CASH_LOAN_PURPOSE_Journey_mean
# client_credit_AMT_CREDIT_LIMIT_ACTUAL_max_sum
# previous_CHANNEL_TYPE_AP+ (Cash loan)_sum
# previous_NAME_GOODS_CATEGORY_Tourism_mean
# previous_NAME_CONTRACT_TYPE_XNA_mean
# previous_AMT_DOWN_PAYMENT_mean
# previous_NAME_GOODS_CATEGORY_Furniture_sum
# previous_CODE_REJECT_REASON_SCOFR_sum
# previous_NAME_YIELD_GROUP_low_normal_sum
# client_cash_MONTHS_BALANCE_sum_mean
# previous_NAME_GOODS_CATEGORY_Homewares_mean
# previous_NAME_SELLER_INDUSTRY_Tourism_mean
# previous_PRODUCT_COMBINATION_POS industry with interest_sum
# previous_NAME_YIELD_GROUP_low_action_sum
# client_cash_CNT_INSTALMENT_min_mean
# previous_CODE_REJECT_REASON_HC_sum
# previous_NAME_YIELD_GROUP_low_normal_mean
# client_cash_NAME_CONTRACT_STATUS_Signed_sum_sum
# previous_PRODUCT_COMBINATION_Cash Street: low_sum
# previous_NAME_PAYMENT_TYPE_Non-cash from your account_mean
# previous_NAME_CASH_LOAN_PURPOSE_Gasification / water supply_mean
# previous_NAME_CASH_LOAN_PURPOSE_Buying a used car_sum
# client_credit_SK_DPD_min_sum
# previous_NAME_PAYMENT_TYPE_Cashless from the account of the employer_mean
# previous_NAME_CONTRACT_TYPE_Revolving loans_sum
# previous_NAME_CASH_LOAN_PURPOSE_Car repairs_mean
# previous_RATE_DOWN_PAYMENT_min
# previous_CNT_PAYMENT_sum
# client_cash_NAME_CONTRACT_STATUS_Returned to the store_sum_mean
# client_installments_AMT_PAYMENT_max_min
# previous_NAME_YIELD_GROUP_high_sum
# client_cash_NAME_CONTRACT_STATUS_Returned to the store_mean_max
# previous_FLAG_LAST_APPL_PER_CONTRACT_N_sum
# previous_NAME_CASH_LOAN_PURPOSE_Repairs_sum
# previous_CHANNEL_TYPE_Channel of corporate sales_mean
# previous_NAME_GOODS_CATEGORY_Vehicles_mean
# previous_NAME_CONTRACT_STATUS_Approved_mean
# client_cash_NAME_CONTRACT_STATUS_Returned to the store_mean_mean
# client_cash_NAME_CONTRACT_STATUS_Approved_sum_mean
# previous_WEEKDAY_APPR_PROCESS_START_FRIDAY_sum
# previous_NAME_GOODS_CATEGORY_Medical Supplies_mean
# previous_PRODUCT_COMBINATION_Card X-Sell_sum
# client_cash_NAME_CONTRACT_STATUS_Returned to the store_mean_min
# previous_PRODUCT_COMBINATION_Card X-Sell_mean
# previous_NAME_GOODS_CATEGORY_Gardening_sum
# client_installments_NUM_INSTALMENT_NUMBER_min_max
# client_credit_AMT_DRAWINGS_POS_CURRENT_sum_sum
# previous_WEEKDAY_APPR_PROCESS_START_SUNDAY_sum
# client_cash_NAME_CONTRACT_STATUS_Active_mean_max
# client_cash_NAME_CONTRACT_STATUS_Canceled_sum_sum
# client_credit_AMT_PAYMENT_TOTAL_CURRENT_min_mean
# previous_NFLAG_INSURED_ON_APPROVAL_sum
# previous_NAME_CASH_LOAN_PURPOSE_Journey_sum
# previous_NAME_CONTRACT_TYPE_XNA_sum
# previous_NAME_CASH_LOAN_PURPOSE_Buying a new car_sum
# previous_NAME_TYPE_SUITE_Family_sum
# previous_NAME_GOODS_CATEGORY_Direct Sales_mean
# previous_NAME_GOODS_CATEGORY_Insurance_mean
# client_credit_SK_DPD_min_mean
# previous_AMT_DOWN_PAYMENT_min
# previous_NAME_CASH_LOAN_PURPOSE_Purchase of electronic equipment_mean
# client_credit_CNT_DRAWINGS_POS_CURRENT_min_sum
# previous_NAME_GOODS_CATEGORY_Computers_mean
# client_credit_AMT_DRAWINGS_CURRENT_min_sum
# client_installments_NUM_INSTALMENT_VERSION_max_min
# previous_PRODUCT_COMBINATION_POS mobile without interest_mean
# client_cash_NAME_CONTRACT_STATUS_Approved_sum_min
# previous_CHANNEL_TYPE_Regional / Local_sum
# client_cash_NAME_CONTRACT_STATUS_Signed_sum_mean
# client_cash_NAME_CONTRACT_STATUS_Signed_sum_min
# previous_CHANNEL_TYPE_Country-wide_mean
# previous_NAME_GOODS_CATEGORY_Consumer Electronics_mean
# client_cash_CNT_INSTALMENT_FUTURE_min_min
# previous_NAME_SELLER_INDUSTRY_Furniture_sum
# previous_NAME_GOODS_CATEGORY_Sport and Leisure_sum
# previous_NAME_YIELD_GROUP_XNA_mean
# previous_WEEKDAY_APPR_PROCESS_START_SUNDAY_mean
# previous_NAME_SELLER_INDUSTRY_Connectivity_sum
# previous_NAME_CASH_LOAN_PURPOSE_Car repairs_sum
# previous_NAME_TYPE_SUITE_Other_B_sum
# previous_NAME_TYPE_SUITE_Spouse, partner_mean
# client_installments_AMT_PAYMENT_min_sum
# previous_NAME_TYPE_SUITE_Group of people_sum
# previous_CODE_REJECT_REASON_SCO_mean
# previous_NAME_GOODS_CATEGORY_Audio/Video_sum
# previous_CODE_REJECT_REASON_HC_mean
# previous_NAME_GOODS_CATEGORY_Mobile_mean
# previous_WEEKDAY_APPR_PROCESS_START_MONDAY_sum
# previous_NAME_GOODS_CATEGORY_Other_sum
# client_credit_AMT_DRAWINGS_OTHER_CURRENT_max_sum
# previous_NAME_CASH_LOAN_PURPOSE_Building a house or an annex_mean
# previous_NAME_PRODUCT_TYPE_XNA_mean
# previous_NAME_GOODS_CATEGORY_Insurance_sum
# previous_NAME_GOODS_CATEGORY_Auto Accessories_sum
# previous_NAME_GOODS_CATEGORY_Sport and Leisure_mean
# previous_PRODUCT_COMBINATION_POS industry with interest_mean
# client_cash_NAME_CONTRACT_STATUS_Returned to the store_sum_sum
# previous_NAME_PORTFOLIO_Cards_sum
# previous_DAYS_FIRST_DUE_mean
# previous_NAME_GOODS_CATEGORY_Consumer Electronics_sum
# previous_NAME_GOODS_CATEGORY_Direct Sales_sum
# previous_NAME_CASH_LOAN_PURPOSE_Buying a home_mean
# previous_NAME_SELLER_INDUSTRY_Connectivity_mean
# previous_NAME_CASH_LOAN_PURPOSE_Buying a new car_mean
# previous_PRODUCT_COMBINATION_Cash Street: high_mean
# client_cash_NAME_CONTRACT_STATUS_Approved_mean_mean
# client_cash_NAME_CONTRACT_STATUS_Signed_mean_max
# previous_CNT_PAYMENT_min
# NAME_CONTRACT_TYPE_Cash loans
# CODE_GENDER_F
# FLAG_OWN_CAR_N
# FLAG_OWN_REALTY_N
# NAME_TYPE_SUITE_Children
# NAME_TYPE_SUITE_Family
# NAME_TYPE_SUITE_Group of people
# NAME_TYPE_SUITE_Other_A
# NAME_TYPE_SUITE_Other_B
# NAME_TYPE_SUITE_Spouse, partner
# NAME_TYPE_SUITE_Unaccompanied
# NAME_INCOME_TYPE_Businessman
# NAME_INCOME_TYPE_Commercial associate
# NAME_INCOME_TYPE_State servant
# NAME_INCOME_TYPE_Student
# NAME_INCOME_TYPE_Unemployed
# NAME_INCOME_TYPE_Working
# NAME_EDUCATION_TYPE_Academic degree
# NAME_EDUCATION_TYPE_Higher education
# NAME_EDUCATION_TYPE_Incomplete higher
# NAME_EDUCATION_TYPE_Lower secondary
# NAME_EDUCATION_TYPE_Secondary / secondary special
# NAME_FAMILY_STATUS_Civil marriage
# NAME_FAMILY_STATUS_Married
# NAME_FAMILY_STATUS_Separated
# NAME_FAMILY_STATUS_Single / not married
# NAME_FAMILY_STATUS_Widow
# NAME_HOUSING_TYPE_Co-op apartment
# NAME_HOUSING_TYPE_House / apartment
# NAME_HOUSING_TYPE_Municipal apartment
# NAME_HOUSING_TYPE_Office apartment
# NAME_HOUSING_TYPE_Rented apartment
# NAME_HOUSING_TYPE_With parents
# OCCUPATION_TYPE_Accountants
# OCCUPATION_TYPE_Cleaning staff
# OCCUPATION_TYPE_Cooking staff
# OCCUPATION_TYPE_Core staff
# OCCUPATION_TYPE_Drivers
# OCCUPATION_TYPE_HR staff
# OCCUPATION_TYPE_High skill tech staff
# OCCUPATION_TYPE_IT staff
# OCCUPATION_TYPE_Laborers
# OCCUPATION_TYPE_Low-skill Laborers
# OCCUPATION_TYPE_Managers
# OCCUPATION_TYPE_Medicine staff
# OCCUPATION_TYPE_Private service staff
# OCCUPATION_TYPE_Realty agents
# OCCUPATION_TYPE_Sales staff
# OCCUPATION_TYPE_Secretaries
# OCCUPATION_TYPE_Security staff
# OCCUPATION_TYPE_Waiters/barmen staff
# WEEKDAY_APPR_PROCESS_START_FRIDAY
# WEEKDAY_APPR_PROCESS_START_MONDAY
# WEEKDAY_APPR_PROCESS_START_SATURDAY
# WEEKDAY_APPR_PROCESS_START_SUNDAY
# WEEKDAY_APPR_PROCESS_START_THURSDAY
# WEEKDAY_APPR_PROCESS_START_TUESDAY
# WEEKDAY_APPR_PROCESS_START_WEDNESDAY
# ORGANIZATION_TYPE_Advertising
# ORGANIZATION_TYPE_Agriculture
# ORGANIZATION_TYPE_Bank
# ORGANIZATION_TYPE_Business Entity Type 1
# ORGANIZATION_TYPE_Business Entity Type 2
# ORGANIZATION_TYPE_Business Entity Type 3
# ORGANIZATION_TYPE_Cleaning
# ORGANIZATION_TYPE_Construction
# ORGANIZATION_TYPE_Culture
# ORGANIZATION_TYPE_Electricity
# ORGANIZATION_TYPE_Emergency
# ORGANIZATION_TYPE_Government
# ORGANIZATION_TYPE_Hotel
# ORGANIZATION_TYPE_Housing
# ORGANIZATION_TYPE_Industry: type 1
# ORGANIZATION_TYPE_Industry: type 10
# ORGANIZATION_TYPE_Industry: type 11
# ORGANIZATION_TYPE_Industry: type 12
# ORGANIZATION_TYPE_Industry: type 13
# ORGANIZATION_TYPE_Industry: type 2
# ORGANIZATION_TYPE_Industry: type 3
# ORGANIZATION_TYPE_Industry: type 4
# ORGANIZATION_TYPE_Industry: type 5
# ORGANIZATION_TYPE_Industry: type 6
# ORGANIZATION_TYPE_Industry: type 7
# ORGANIZATION_TYPE_Industry: type 8
# ORGANIZATION_TYPE_Industry: type 9
# ORGANIZATION_TYPE_Insurance
# ORGANIZATION_TYPE_Kindergarten
# ORGANIZATION_TYPE_Legal Services
# ORGANIZATION_TYPE_Medicine
# ORGANIZATION_TYPE_Military
# ORGANIZATION_TYPE_Mobile
# ORGANIZATION_TYPE_Other
# ORGANIZATION_TYPE_Police
# ORGANIZATION_TYPE_Postal
# ORGANIZATION_TYPE_Realtor
# ORGANIZATION_TYPE_Religion
# ORGANIZATION_TYPE_Restaurant
# ORGANIZATION_TYPE_School
# ORGANIZATION_TYPE_Security
# ORGANIZATION_TYPE_Security Ministries
# ORGANIZATION_TYPE_Self-employed
# ORGANIZATION_TYPE_Services
# ORGANIZATION_TYPE_Telecom
# ORGANIZATION_TYPE_Trade: type 1
# ORGANIZATION_TYPE_Trade: type 2
# ORGANIZATION_TYPE_Trade: type 3
# ORGANIZATION_TYPE_Trade: type 4
# ORGANIZATION_TYPE_Trade: type 5
# ORGANIZATION_TYPE_Trade: type 6
# ORGANIZATION_TYPE_Trade: type 7
# ORGANIZATION_TYPE_Transport: type 1
# ORGANIZATION_TYPE_Transport: type 2
# ORGANIZATION_TYPE_Transport: type 3
# ORGANIZATION_TYPE_Transport: type 4
# ORGANIZATION_TYPE_University
# FONDKAPREMONT_MODE_not specified
# FONDKAPREMONT_MODE_org spec account
# FONDKAPREMONT_MODE_reg oper account
# FONDKAPREMONT_MODE_reg oper spec account
# HOUSETYPE_MODE_block of flats
# HOUSETYPE_MODE_specific housing
# HOUSETYPE_MODE_terraced house
# WALLSMATERIAL_MODE_Block
# WALLSMATERIAL_MODE_Mixed
# WALLSMATERIAL_MODE_Monolithic
# WALLSMATERIAL_MODE_Others
# WALLSMATERIAL_MODE_Panel
# WALLSMATERIAL_MODE_Stone, brick
# WALLSMATERIAL_MODE_Wooden
# EMERGENCYSTATE_MODE_Yes

# %%
import re
train = train.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))
test = test.rename(columns = lambda x:re.sub('[^A-Za-z0-9_]+', '', x))

# %%
for col in train.columns:
    print(col)
# Out:
# CNT_CHILDREN
# AMT_INCOME_TOTAL
# AMT_CREDIT
# AMT_ANNUITY
# REGION_POPULATION_RELATIVE
# DAYS_BIRTH
# DAYS_EMPLOYED
# DAYS_REGISTRATION
# DAYS_ID_PUBLISH
# OWN_CAR_AGE
# FLAG_MOBIL
# FLAG_WORK_PHONE
# FLAG_CONT_MOBILE
# FLAG_PHONE
# FLAG_EMAIL
# CNT_FAM_MEMBERS
# REGION_RATING_CLIENT
# HOUR_APPR_PROCESS_START
# REG_REGION_NOT_LIVE_REGION
# REG_REGION_NOT_WORK_REGION
# LIVE_REGION_NOT_WORK_REGION
# REG_CITY_NOT_LIVE_CITY
# REG_CITY_NOT_WORK_CITY
# LIVE_CITY_NOT_WORK_CITY
# EXT_SOURCE_1
# EXT_SOURCE_2
# EXT_SOURCE_3
# APARTMENTS_AVG
# BASEMENTAREA_AVG
# YEARS_BEGINEXPLUATATION_AVG
# YEARS_BUILD_AVG
# COMMONAREA_AVG
# ELEVATORS_AVG
# ENTRANCES_AVG
# FLOORSMAX_AVG
# FLOORSMIN_AVG
# LANDAREA_AVG
# NONLIVINGAPARTMENTS_AVG
# NONLIVINGAREA_AVG
# OBS_30_CNT_SOCIAL_CIRCLE
# DEF_30_CNT_SOCIAL_CIRCLE
# DEF_60_CNT_SOCIAL_CIRCLE
# DAYS_LAST_PHONE_CHANGE
# FLAG_DOCUMENT_2
# FLAG_DOCUMENT_3
# FLAG_DOCUMENT_4
# FLAG_DOCUMENT_5
# FLAG_DOCUMENT_6
# FLAG_DOCUMENT_7
# FLAG_DOCUMENT_8
# FLAG_DOCUMENT_9
# FLAG_DOCUMENT_10
# FLAG_DOCUMENT_11
# FLAG_DOCUMENT_12
# FLAG_DOCUMENT_13
# FLAG_DOCUMENT_14
# FLAG_DOCUMENT_15
# FLAG_DOCUMENT_16
# FLAG_DOCUMENT_17
# FLAG_DOCUMENT_18
# FLAG_DOCUMENT_19
# FLAG_DOCUMENT_20
# FLAG_DOCUMENT_21
# AMT_REQ_CREDIT_BUREAU_HOUR
# AMT_REQ_CREDIT_BUREAU_DAY
# AMT_REQ_CREDIT_BUREAU_WEEK
# AMT_REQ_CREDIT_BUREAU_MON
# AMT_REQ_CREDIT_BUREAU_QRT
# AMT_REQ_CREDIT_BUREAU_YEAR
# bureau_CREDIT_ACTIVE_Active_count
# bureau_CREDIT_ACTIVE_Active_count_norm
# bureau_CREDIT_ACTIVE_Baddebt_count
# bureau_CREDIT_ACTIVE_Baddebt_count_norm
# bureau_CREDIT_ACTIVE_Closed_count
# bureau_CREDIT_ACTIVE_Sold_count
# bureau_CREDIT_ACTIVE_Sold_count_norm
# bureau_CREDIT_CURRENCY_currency1_count_norm
# bureau_CREDIT_CURRENCY_currency2_count
# bureau_CREDIT_CURRENCY_currency3_count
# bureau_CREDIT_CURRENCY_currency3_count_norm
# bureau_CREDIT_CURRENCY_currency4_count
# bureau_CREDIT_CURRENCY_currency4_count_norm
# bureau_CREDIT_TYPE_Anothertypeofloan_count
# bureau_CREDIT_TYPE_Anothertypeofloan_count_norm
# bureau_CREDIT_TYPE_Carloan_count
# bureau_CREDIT_TYPE_Carloan_count_norm
# bureau_CREDIT_TYPE_Cashloannonearmarked_count
# bureau_CREDIT_TYPE_Cashloannonearmarked_count_norm
# bureau_CREDIT_TYPE_Consumercredit_count_norm
# bureau_CREDIT_TYPE_Creditcard_count
# bureau_CREDIT_TYPE_Creditcard_count_norm
# bureau_CREDIT_TYPE_Interbankcredit_count
# bureau_CREDIT_TYPE_Loanforbusinessdevelopment_count
# bureau_CREDIT_TYPE_Loanforbusinessdevelopment_count_norm
# bureau_CREDIT_TYPE_Loanforpurchaseofsharesmarginlending_count
# bureau_CREDIT_TYPE_Loanforpurchaseofsharesmarginlending_count_norm
# bureau_CREDIT_TYPE_Loanforthepurchaseofequipment_count
# bureau_CREDIT_TYPE_Loanforthepurchaseofequipment_count_norm
# bureau_CREDIT_TYPE_Loanforworkingcapitalreplenishment_count
# bureau_CREDIT_TYPE_Loanforworkingcapitalreplenishment_count_norm
# bureau_CREDIT_TYPE_Microloan_count
# bureau_CREDIT_TYPE_Microloan_count_norm
# bureau_CREDIT_TYPE_Mobileoperatorloan_count
# bureau_CREDIT_TYPE_Mortgage_count
# bureau_CREDIT_TYPE_Mortgage_count_norm
# bureau_CREDIT_TYPE_Realestateloan_count
# bureau_CREDIT_TYPE_Realestateloan_count_norm
# bureau_CREDIT_TYPE_Unknowntypeofloan_count
# bureau_CREDIT_TYPE_Unknowntypeofloan_count_norm
# bureau_DAYS_CREDIT_mean
# bureau_DAYS_CREDIT_max
# bureau_DAYS_CREDIT_min
# bureau_DAYS_CREDIT_sum
# bureau_CREDIT_DAY_OVERDUE_mean
# bureau_CREDIT_DAY_OVERDUE_max
# bureau_CREDIT_DAY_OVERDUE_min
# bureau_DAYS_CREDIT_ENDDATE_mean
# bureau_DAYS_CREDIT_ENDDATE_max
# bureau_DAYS_CREDIT_ENDDATE_min
# bureau_DAYS_CREDIT_ENDDATE_sum
# bureau_DAYS_ENDDATE_FACT_mean
# bureau_DAYS_ENDDATE_FACT_max
# bureau_DAYS_ENDDATE_FACT_min
# bureau_AMT_CREDIT_MAX_OVERDUE_count
# bureau_AMT_CREDIT_MAX_OVERDUE_mean
# bureau_CNT_CREDIT_PROLONG_mean
# bureau_CNT_CREDIT_PROLONG_max
# bureau_CNT_CREDIT_PROLONG_min
# bureau_AMT_CREDIT_SUM_mean
# bureau_AMT_CREDIT_SUM_max
# bureau_AMT_CREDIT_SUM_min
# bureau_AMT_CREDIT_SUM_sum
# bureau_AMT_CREDIT_SUM_DEBT_mean
# bureau_AMT_CREDIT_SUM_DEBT_max
# bureau_AMT_CREDIT_SUM_DEBT_min
# bureau_AMT_CREDIT_SUM_LIMIT_mean
# bureau_AMT_CREDIT_SUM_LIMIT_max
# bureau_AMT_CREDIT_SUM_LIMIT_min
# bureau_AMT_CREDIT_SUM_OVERDUE_mean
# bureau_AMT_CREDIT_SUM_OVERDUE_max
# bureau_AMT_CREDIT_SUM_OVERDUE_min
# bureau_DAYS_CREDIT_UPDATE_mean
# bureau_DAYS_CREDIT_UPDATE_max
# bureau_DAYS_CREDIT_UPDATE_min
# bureau_AMT_ANNUITY_count
# bureau_AMT_ANNUITY_mean
# bureau_AMT_ANNUITY_max
# bureau_AMT_ANNUITY_min
# client_bureau_balance_MONTHS_BALANCE_count_mean
# client_bureau_balance_MONTHS_BALANCE_count_max
# client_bureau_balance_MONTHS_BALANCE_count_min
# client_bureau_balance_MONTHS_BALANCE_count_sum
# client_bureau_balance_MONTHS_BALANCE_mean_min
# client_bureau_balance_MONTHS_BALANCE_max_mean
# client_bureau_balance_MONTHS_BALANCE_max_max
# client_bureau_balance_MONTHS_BALANCE_max_min
# client_bureau_balance_MONTHS_BALANCE_max_sum
# client_bureau_balance_STATUS_0_count_mean
# client_bureau_balance_STATUS_0_count_max
# client_bureau_balance_STATUS_0_count_min
# client_bureau_balance_STATUS_0_count_sum
# client_bureau_balance_STATUS_0_count_norm_mean
# client_bureau_balance_STATUS_0_count_norm_max
# client_bureau_balance_STATUS_0_count_norm_min
# client_bureau_balance_STATUS_0_count_norm_sum
# client_bureau_balance_STATUS_1_count_mean
# client_bureau_balance_STATUS_1_count_max
# client_bureau_balance_STATUS_1_count_min
# client_bureau_balance_STATUS_1_count_sum
# client_bureau_balance_STATUS_1_count_norm_mean
# client_bureau_balance_STATUS_1_count_norm_max
# client_bureau_balance_STATUS_1_count_norm_min
# client_bureau_balance_STATUS_1_count_norm_sum
# client_bureau_balance_STATUS_2_count_mean
# client_bureau_balance_STATUS_2_count_max
# client_bureau_balance_STATUS_2_count_min
# client_bureau_balance_STATUS_2_count_sum
# client_bureau_balance_STATUS_2_count_norm_mean
# client_bureau_balance_STATUS_2_count_norm_max
# client_bureau_balance_STATUS_2_count_norm_min
# client_bureau_balance_STATUS_2_count_norm_sum
# client_bureau_balance_STATUS_3_count_mean
# client_bureau_balance_STATUS_3_count_max
# client_bureau_balance_STATUS_3_count_min
# client_bureau_balance_STATUS_3_count_sum
# client_bureau_balance_STATUS_3_count_norm_mean
# client_bureau_balance_STATUS_3_count_norm_max
# client_bureau_balance_STATUS_3_count_norm_min
# client_bureau_balance_STATUS_3_count_norm_sum
# client_bureau_balance_STATUS_4_count_mean
# client_bureau_balance_STATUS_4_count_max
# client_bureau_balance_STATUS_4_count_min
# client_bureau_balance_STATUS_4_count_sum
# client_bureau_balance_STATUS_4_count_norm_mean
# client_bureau_balance_STATUS_4_count_norm_max
# client_bureau_balance_STATUS_4_count_norm_min
# client_bureau_balance_STATUS_4_count_norm_sum
# client_bureau_balance_STATUS_5_count_mean
# client_bureau_balance_STATUS_5_count_max
# client_bureau_balance_STATUS_5_count_min
# client_bureau_balance_STATUS_5_count_sum
# client_bureau_balance_STATUS_5_count_norm_max
# client_bureau_balance_STATUS_5_count_norm_min
# client_bureau_balance_STATUS_5_count_norm_sum
# client_bureau_balance_STATUS_C_count_mean
# client_bureau_balance_STATUS_C_count_max
# client_bureau_balance_STATUS_C_count_min
# client_bureau_balance_STATUS_C_count_norm_mean
# client_bureau_balance_STATUS_C_count_norm_max
# client_bureau_balance_STATUS_C_count_norm_min
# client_bureau_balance_STATUS_X_count_mean
# client_bureau_balance_STATUS_X_count_max
# client_bureau_balance_STATUS_X_count_min
# client_bureau_balance_STATUS_X_count_sum
# client_bureau_balance_STATUS_X_count_norm_mean
# client_bureau_balance_STATUS_X_count_norm_max
# client_bureau_balance_STATUS_X_count_norm_min
# client_bureau_balance_STATUS_X_count_norm_sum
# client_credit_AMT_INST_MIN_REGULARITY_max_max
# previous_CHANNEL_TYPE_Creditandcashoffices_mean
# client_installments_DAYS_ENTRY_PAYMENT_max_max
# previous_DAYS_DECISION_min
# previous_NAME_CONTRACT_TYPE_Cashloans_count
# client_credit_CNT_DRAWINGS_CURRENT_sum_mean
# previous_PRODUCT_COMBINATION_CashStreetmiddle_sum
# client_credit_AMT_PAYMENT_TOTAL_CURRENT_max_sum
# client_cash_NAME_CONTRACT_STATUS_XNA_sum_max
# previous_DAYS_TERMINATION_mean
# previous_CHANNEL_TYPE_Channelofcorporatesales_sum
# previous_NAME_CONTRACT_STATUS_Refused_sum
# previous_DAYS_FIRST_DUE_min
# previous_NAME_GOODS_CATEGORY_HouseConstruction_mean
# client_cash_CNT_INSTALMENT_FUTURE_min_max
# client_cash_NAME_CONTRACT_STATUS_Completed_mean_max
# previous_NAME_GOODS_CATEGORY_Homewares_sum
# client_credit_CNT_DRAWINGS_OTHER_CURRENT_min_sum
# client_credit_NAME_CONTRACT_STATUS_Refused_mean_mean
# client_cash_NAME_CONTRACT_STATUS_Signed_sum_max
# client_installments_AMT_INSTALMENT_max_mean
# client_cash_NAME_CONTRACT_STATUS_Active_mean_mean
# previous_WEEKDAY_APPR_PROCESS_START_SATURDAY_mean
# client_credit_SK_DPD_DEF_max_sum
# client_credit_CNT_DRAWINGS_ATM_CURRENT_sum_min
# previous_NAME_SELLER_INDUSTRY_MLMpartners_mean
# client_credit_AMT_RECEIVABLE_PRINCIPAL_min_sum
# previous_DAYS_FIRST_DRAWING_min
# client_cash_SK_DPD_DEF_max_min
# client_cash_NAME_CONTRACT_STATUS_Demand_sum_max
# client_cash_NAME_CONTRACT_STATUS_Approved_mean_min
# previous_NAME_GOODS_CATEGORY_Weapon_sum
# previous_AMT_ANNUITY_max
# previous_PRODUCT_COMBINATION_POSmobilewithoutinterest_sum
# client_cash_NAME_CONTRACT_STATUS_Canceled_mean_min
# client_cash_CNT_INSTALMENT_FUTURE_min_count
# client_credit_AMT_INST_MIN_REGULARITY_sum_min
# client_cash_NAME_CONTRACT_STATUS_Approved_mean_max
# client_credit_AMT_DRAWINGS_POS_CURRENT_mean_sum
# previous_PRODUCT_COMBINATION_CashXSelllow_sum
# client_cash_NAME_CONTRACT_STATUS_Demand_mean_min
# client_cash_CNT_INSTALMENT_min_min
# client_installments_AMT_PAYMENT_min_mean
# previous_NAME_PRODUCT_TYPE_xsell_mean
# client_cash_CNT_INSTALMENT_FUTURE_min_mean
# client_credit_AMT_DRAWINGS_CURRENT_max_max
# previous_PRODUCT_COMBINATION_POShouseholdwithoutinterest_mean
# client_credit_AMT_TOTAL_RECEIVABLE_min_max
# client_cash_NAME_CONTRACT_STATUS_Returnedtothestore_sum_max
# client_installments_NUM_INSTALMENT_VERSION_count_max
# client_credit_CNT_DRAWINGS_CURRENT_min_sum
# previous_CODE_REJECT_REASON_SYSTEM_mean
# previous_NAME_CASH_LOAN_PURPOSE_Education_mean
# previous_NFLAG_INSURED_ON_APPROVAL_mean
# client_credit_NAME_CONTRACT_STATUS_Demand_sum_min
# client_credit_NAME_CONTRACT_STATUS_Sentproposal_sum_mean
# previous_NAME_TYPE_SUITE_Family_mean
# client_credit_CNT_INSTALMENT_MATURE_CUM_max_sum
# client_credit_MONTHS_BALANCE_max_mean
# client_cash_CNT_INSTALMENT_mean_max
# client_cash_CNT_INSTALMENT_count_mean
# client_credit_AMT_INST_MIN_REGULARITY_mean_min
# previous_NFLAG_INSURED_ON_APPROVAL_min
# previous_NAME_SELLER_INDUSTRY_Clothing_mean
# client_cash_NAME_CONTRACT_STATUS_Canceled_sum_mean
# previous_NAME_CASH_LOAN_PURPOSE_Buyingausedcar_mean
# previous_NAME_PRODUCT_TYPE_xsell_sum
# client_cash_CNT_INSTALMENT_sum_min
# client_installments_AMT_INSTALMENT_mean_min
# client_credit_AMT_CREDIT_LIMIT_ACTUAL_sum_sum
# previous_NAME_CASH_LOAN_PURPOSE_Businessdevelopment_mean
# previous_RATE_INTEREST_PRIMARY_sum
# previous_HOUR_APPR_PROCESS_START_min
# client_cash_NAME_CONTRACT_STATUS_Demand_mean_max
# previous_NAME_SELLER_INDUSTRY_Industry_mean
# client_credit_AMT_CREDIT_LIMIT_ACTUAL_max_max
# client_cash_NAME_CONTRACT_STATUS_Amortizeddebt_mean_sum
# client_cash_CNT_INSTALMENT_FUTURE_mean_sum
# previous_NAME_CASH_LOAN_PURPOSE_Paymentsonotherloans_mean
# previous_NAME_CASH_LOAN_PURPOSE_Buyingahome_sum
# previous_PRODUCT_COMBINATION_CashXSellhigh_sum
# previous_NAME_CASH_LOAN_PURPOSE_Refusaltonamethegoal_sum
# client_cash_CNT_INSTALMENT_mean_min
# client_credit_CNT_DRAWINGS_ATM_CURRENT_sum_sum
# client_credit_AMT_DRAWINGS_CURRENT_min_min
# client_credit_AMT_PAYMENT_TOTAL_CURRENT_mean_sum
# client_cash_NAME_CONTRACT_STATUS_Active_count_min
# client_cash_NAME_CONTRACT_STATUS_Active_sum_sum
# client_credit_AMT_DRAWINGS_CURRENT_mean_max
# client_credit_AMT_DRAWINGS_OTHER_CURRENT_mean_sum
# previous_NAME_CASH_LOAN_PURPOSE_XNA_sum
# client_credit_AMT_DRAWINGS_ATM_CURRENT_sum_mean
# client_cash_NAME_CONTRACT_STATUS_Canceled_mean_sum
# previous_CHANNEL_TYPE_Stone_sum
# previous_NAME_PRODUCT_TYPE_walkin_mean
# previous_DAYS_LAST_DUE_1ST_VERSION_mean
# previous_AMT_ANNUITY_min
# previous_NAME_SELLER_INDUSTRY_Tourism_sum
# previous_RATE_DOWN_PAYMENT_mean
# previous_RATE_INTEREST_PRIVILEGED_sum
# previous_NAME_SELLER_INDUSTRY_Jewelry_sum
# previous_CHANNEL_TYPE_Contactcenter_mean
# client_cash_SK_DPD_mean_min
# client_installments_DAYS_INSTALMENT_max_sum
# previous_NAME_CONTRACT_TYPE_Consumerloans_mean
# client_credit_CNT_DRAWINGS_OTHER_CURRENT_sum_min
# client_credit_AMT_PAYMENT_TOTAL_CURRENT_sum_sum
# client_credit_NAME_CONTRACT_STATUS_Active_mean_mean
# previous_NAME_YIELD_GROUP_middle_mean
# previous_NAME_TYPE_SUITE_Unaccompanied_sum
# client_installments_AMT_PAYMENT_max_sum
# client_installments_NUM_INSTALMENT_NUMBER_sum_min
# client_credit_AMT_DRAWINGS_CURRENT_max_sum
# previous_NAME_SELLER_INDUSTRY_MLMpartners_sum
# previous_CODE_REJECT_REASON_SCOFR_mean
# previous_DAYS_DECISION_max
# client_cash_SK_DPD_min_min
# previous_PRODUCT_COMBINATION_POSmobilewithinterest_mean
# previous_NAME_GOODS_CATEGORY_AdditionalService_mean
# previous_CODE_REJECT_REASON_XNA_mean
# client_installments_NUM_INSTALMENT_NUMBER_min_min
# previous_PRODUCT_COMBINATION_CardStreet_sum
# previous_NAME_CASH_LOAN_PURPOSE_Education_sum
# client_cash_SK_DPD_DEF_min_sum
# client_credit_SK_DPD_sum_min
# client_credit_AMT_BALANCE_max_sum
# client_cash_NAME_CONTRACT_STATUS_Completed_sum_sum
# client_cash_SK_DPD_min_sum
# previous_PRODUCT_COMBINATION_POShouseholdwithinterest_mean
# previous_NAME_GOODS_CATEGORY_AudioVideo_mean
# previous_NAME_PRODUCT_TYPE_XNA_sum
# previous_DAYS_DECISION_mean
# previous_NAME_PAYMENT_TYPE_Noncashfromyouraccount_sum
# previous_AMT_GOODS_PRICE_max
# client_credit_AMT_DRAWINGS_ATM_CURRENT_min_sum
# client_credit_CNT_DRAWINGS_POS_CURRENT_sum_sum
# previous_NAME_GOODS_CATEGORY_AutoAccessories_mean
# previous_NAME_PORTFOLIO_Cash_sum
# client_installments_DAYS_INSTALMENT_min_max
# client_installments_NUM_INSTALMENT_VERSION_sum_max
# previous_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_mean
# previous_NAME_PRODUCT_TYPE_walkin_sum
# client_credit_NAME_CONTRACT_STATUS_Approved_mean_sum
# previous_NAME_GOODS_CATEGORY_Weapon_mean
# previous_DAYS_LAST_DUE_1ST_VERSION_sum
# previous_FLAG_LAST_APPL_PER_CONTRACT_N_mean
# client_cash_SK_DPD_mean_mean
# client_cash_SK_DPD_DEF_max_sum
# client_credit_AMT_CREDIT_LIMIT_ACTUAL_min_sum
# previous_DAYS_FIRST_DRAWING_sum
# client_installments_NUM_INSTALMENT_VERSION_mean_min
# previous_NAME_GOODS_CATEGORY_Vehicles_sum
# previous_SELLERPLACE_AREA_sum
# previous_NAME_CASH_LOAN_PURPOSE_Businessdevelopment_sum
# client_credit_CNT_DRAWINGS_ATM_CURRENT_min_sum
# client_credit_CNT_DRAWINGS_CURRENT_max_max
# client_credit_AMT_PAYMENT_CURRENT_min_sum
# client_installments_DAYS_ENTRY_PAYMENT_max_mean
# previous_NAME_CASH_LOAN_PURPOSE_Buyingaholidayhomeland_sum
# client_cash_NAME_CONTRACT_STATUS_Completed_sum_min
# previous_PRODUCT_COMBINATION_CardStreet_mean
# previous_AMT_DOWN_PAYMENT_sum
# previous_WEEKDAY_APPR_PROCESS_START_WEDNESDAY_sum
# previous_NAME_CASH_LOAN_PURPOSE_Buyingagarage_mean
# previous_PRODUCT_COMBINATION_CashXSelllow_mean
# previous_NAME_CASH_LOAN_PURPOSE_Medicine_sum
# previous_CODE_REJECT_REASON_LIMIT_mean
# previous_NAME_GOODS_CATEGORY_Jewelry_sum
# previous_PRODUCT_COMBINATION_POSotherwithinterest_sum
# client_credit_AMT_DRAWINGS_POS_CURRENT_min_sum
# previous_NFLAG_INSURED_ON_APPROVAL_max
# previous_PRODUCT_COMBINATION_CashStreetmiddle_mean
# client_credit_NAME_CONTRACT_STATUS_Signed_mean_max
# previous_NAME_GOODS_CATEGORY_ConstructionMaterials_sum
# previous_RATE_DOWN_PAYMENT_sum
# previous_CHANNEL_TYPE_Contactcenter_sum
# previous_CODE_REJECT_REASON_VERIF_mean
# client_credit_CNT_DRAWINGS_CURRENT_mean_mean
# previous_NAME_PORTFOLIO_Cars_sum
# previous_NAME_GOODS_CATEGORY_Mobile_sum
# previous_NAME_SELLER_INDUSTRY_Construction_mean
# client_cash_NAME_CONTRACT_STATUS_Amortizeddebt_sum_min
# client_cash_CNT_INSTALMENT_sum_mean
# previous_CODE_REJECT_REASON_SYSTEM_sum
# previous_DAYS_TERMINATION_sum
# previous_PRODUCT_COMBINATION_CashStreethigh_sum
# previous_PRODUCT_COMBINATION_POSotherwithinterest_mean
# client_credit_AMT_DRAWINGS_POS_CURRENT_max_sum
# client_credit_AMT_CREDIT_LIMIT_ACTUAL_min_mean
# previous_NAME_GOODS_CATEGORY_Education_sum
# client_installments_AMT_PAYMENT_mean_max
# client_credit_AMT_CREDIT_LIMIT_ACTUAL_sum_min
# client_credit_CNT_DRAWINGS_CURRENT_max_sum
# previous_NAME_PORTFOLIO_XNA_sum
# client_installments_AMT_PAYMENT_min_min
# previous_NAME_CLIENT_TYPE_XNA_mean
# previous_NAME_TYPE_SUITE_Other_B_mean
# previous_NAME_CASH_LOAN_PURPOSE_Medicine_mean
# client_cash_CNT_INSTALMENT_min_max
# client_installments_NUM_INSTALMENT_VERSION_max_max
# previous_SELLERPLACE_AREA_mean
# previous_NAME_CASH_LOAN_PURPOSE_Paymentsonotherloans_sum
# client_installments_DAYS_ENTRY_PAYMENT_count_min
# previous_NAME_CASH_LOAN_PURPOSE_Buildingahouseoranannex_sum
# client_installments_AMT_INSTALMENT_sum_mean
# previous_CODE_REJECT_REASON_SCO_sum
# previous_NAME_SELLER_INDUSTRY_Furniture_mean
# client_cash_SK_DPD_max_min
# client_installments_AMT_PAYMENT_min_max
# previous_PRODUCT_COMBINATION_CashXSellmiddle_mean
# previous_NAME_SELLER_INDUSTRY_Autotechnology_mean
# client_credit_CNT_DRAWINGS_CURRENT_min_mean
# client_installments_DAYS_ENTRY_PAYMENT_min_count
# client_credit_NAME_CONTRACT_STATUS_Completed_mean_sum
# previous_PRODUCT_COMBINATION_POShouseholdwithinterest_sum
# previous_NAME_CASH_LOAN_PURPOSE_Buyingaholidayhomeland_mean
# client_credit_CNT_DRAWINGS_ATM_CURRENT_max_sum
# previous_AMT_ANNUITY_mean
# client_installments_NUM_INSTALMENT_NUMBER_min_mean
# previous_PRODUCT_COMBINATION_POSotherswithoutinterest_sum
# client_credit_CNT_INSTALMENT_MATURE_CUM_min_min
# client_cash_NAME_CONTRACT_STATUS_Signed_mean_mean
# previous_NAME_CASH_LOAN_PURPOSE_Gasificationwatersupply_sum
# previous_DAYS_FIRST_DRAWING_max
# previous_NAME_GOODS_CATEGORY_Gardening_mean
# client_cash_NAME_CONTRACT_STATUS_Completed_mean_sum
# client_installments_AMT_INSTALMENT_mean_mean
# previous_CODE_REJECT_REASON_XAP_mean
# previous_CHANNEL_TYPE_APCashloan_mean
# previous_NAME_PORTFOLIO_XNA_mean
# previous_CODE_REJECT_REASON_XNA_sum
# client_installments_AMT_PAYMENT_sum_min
# client_credit_CNT_DRAWINGS_OTHER_CURRENT_max_sum
# previous_PRODUCT_COMBINATION_POShouseholdwithoutinterest_sum
# previous_NAME_GOODS_CATEGORY_Animals_mean
# client_installments_AMT_PAYMENT_mean_sum
# client_cash_CNT_INSTALMENT_FUTURE_mean_mean
# previous_NAME_TYPE_SUITE_Unaccompanied_mean
# previous_CODE_REJECT_REASON_LIMIT_sum
# previous_AMT_ANNUITY_sum
# previous_NAME_TYPE_SUITE_Other_A_sum
# previous_NAME_SELLER_INDUSTRY_Industry_sum
# client_credit_NAME_CONTRACT_STATUS_Signed_sum_max
# previous_HOUR_APPR_PROCESS_START_max
# previous_WEEKDAY_APPR_PROCESS_START_MONDAY_mean
# previous_NAME_TYPE_SUITE_Children_sum
# previous_DAYS_LAST_DUE_max
# previous_PRODUCT_COMBINATION_CashXSellmiddle_sum
# previous_NAME_CASH_LOAN_PURPOSE_Buyingagarage_sum
# previous_CHANNEL_TYPE_Cardealer_mean
# previous_PRODUCT_COMBINATION_POSotherswithoutinterest_mean
# client_cash_SK_DPD_DEF_min_min
# previous_NAME_CONTRACT_STATUS_Canceled_mean
# client_installments_NUM_INSTALMENT_VERSION_max_mean
# previous_NAME_GOODS_CATEGORY_ConstructionMaterials_mean
# previous_NAME_GOODS_CATEGORY_ClothingandAccessories_sum
# previous_WEEKDAY_APPR_PROCESS_START_TUESDAY_sum
# previous_NAME_GOODS_CATEGORY_Tourism_sum
# client_credit_AMT_RECIVABLE_sum_sum
# client_installments_AMT_PAYMENT_sum_max
# client_installments_NUM_INSTALMENT_VERSION_min_max
# previous_NAME_GOODS_CATEGORY_MedicalSupplies_sum
# client_cash_NAME_CONTRACT_STATUS_Completed_mean_min
# client_installments_NUM_INSTALMENT_VERSION_sum_mean
# client_credit_CNT_DRAWINGS_POS_CURRENT_max_sum
# previous_NAME_CASH_LOAN_PURPOSE_Furniture_mean
# client_installments_NUM_INSTALMENT_NUMBER_max_max
# previous_PRODUCT_COMBINATION_CashStreetlow_mean
# previous_NAME_SELLER_INDUSTRY_Consumerelectronics_sum
# previous_NAME_GOODS_CATEGORY_AdditionalService_sum
# previous_PRODUCT_COMBINATION_POSindustrywithoutinterest_mean
# previous_NAME_PORTFOLIO_Cash_mean
# previous_NAME_CASH_LOAN_PURPOSE_XAP_sum
# previous_NAME_GOODS_CATEGORY_Medicine_sum
# previous_NAME_YIELD_GROUP_high_mean
# client_cash_MONTHS_BALANCE_sum_max
# previous_NAME_CASH_LOAN_PURPOSE_Weddinggiftholiday_mean
# client_credit_AMT_INST_MIN_REGULARITY_min_sum
# previous_NAME_SELLER_INDUSTRY_Autotechnology_sum
# previous_NAME_CASH_LOAN_PURPOSE_Everydayexpenses_mean
# previous_AMT_GOODS_PRICE_min
# client_credit_CNT_DRAWINGS_CURRENT_sum_sum
# previous_NAME_CASH_LOAN_PURPOSE_Other_sum
# previous_NAME_SELLER_INDUSTRY_Consumerelectronics_mean
# previous_CODE_REJECT_REASON_VERIF_sum
# previous_NAME_TYPE_SUITE_Spousepartner_sum
# previous_NAME_CONTRACT_TYPE_Revolvingloans_mean
# client_credit_AMT_INST_MIN_REGULARITY_min_min
# previous_DAYS_FIRST_DUE_sum
# client_credit_CNT_DRAWINGS_OTHER_CURRENT_sum_sum
# previous_WEEKDAY_APPR_PROCESS_START_SATURDAY_sum
# previous_NAME_GOODS_CATEGORY_Fitness_sum
# previous_NAME_CLIENT_TYPE_New_mean
# previous_NAME_CASH_LOAN_PURPOSE_Repairs_mean
# previous_AMT_GOODS_PRICE_mean
# client_installments_AMT_INSTALMENT_min_sum
# previous_NAME_CASH_LOAN_PURPOSE_Hobby_mean
# previous_NAME_SELLER_INDUSTRY_Jewelry_mean
# client_cash_NAME_CONTRACT_STATUS_Active_mean_min
# previous_NAME_GOODS_CATEGORY_OfficeAppliances_sum
# previous_NAME_CONTRACT_STATUS_Unusedoffer_sum
# previous_CHANNEL_TYPE_Stone_mean
# client_cash_NAME_CONTRACT_STATUS_Signed_mean_min
# previous_NAME_CLIENT_TYPE_Refreshed_mean
# previous_DAYS_LAST_DUE_min
# previous_CHANNEL_TYPE_Countrywide_sum
# previous_AMT_DOWN_PAYMENT_count
# client_installments_NUM_INSTALMENT_VERSION_sum_min
# previous_WEEKDAY_APPR_PROCESS_START_THURSDAY_mean
# previous_NAME_TYPE_SUITE_Groupofpeople_mean
# previous_DAYS_DECISION_sum
# previous_WEEKDAY_APPR_PROCESS_START_THURSDAY_sum
# client_credit_AMT_DRAWINGS_OTHER_CURRENT_sum_sum
# client_installments_NUM_INSTALMENT_NUMBER_max_min
# client_installments_AMT_INSTALMENT_max_max
# previous_WEEKDAY_APPR_PROCESS_START_FRIDAY_mean
# previous_NAME_GOODS_CATEGORY_Education_mean
# client_cash_NAME_CONTRACT_STATUS_Returnedtothestore_sum_min
# client_cash_NAME_CONTRACT_STATUS_Approved_sum_sum
# previous_PRODUCT_COMBINATION_CashXSellhigh_mean
# previous_NAME_TYPE_SUITE_Other_A_mean
# previous_NAME_CONTRACT_STATUS_Unusedoffer_mean
# previous_NAME_GOODS_CATEGORY_Jewelry_mean
# previous_NAME_GOODS_CATEGORY_Other_mean
# previous_CHANNEL_TYPE_RegionalLocal_mean
# previous_NAME_CASH_LOAN_PURPOSE_Urgentneeds_mean
# client_credit_MONTHS_BALANCE_max_sum
# previous_NAME_CASH_LOAN_PURPOSE_Other_mean
# previous_NAME_CLIENT_TYPE_Repeater_mean
# previous_NAME_YIELD_GROUP_middle_sum
# previous_CNT_PAYMENT_max
# previous_PRODUCT_COMBINATION_Cash_mean
# client_cash_CNT_INSTALMENT_FUTURE_min_sum
# client_cash_NAME_CONTRACT_STATUS_Approved_mean_sum
# previous_NAME_CASH_LOAN_PURPOSE_Hobby_sum
# previous_NAME_CASH_LOAN_PURPOSE_Refusaltonamethegoal_mean
# previous_NAME_GOODS_CATEGORY_HouseConstruction_sum
# previous_NAME_GOODS_CATEGORY_Medicine_mean
# previous_NAME_CASH_LOAN_PURPOSE_Furniture_sum
# client_cash_NAME_CONTRACT_STATUS_XNA_mean_min
# previous_NAME_CLIENT_TYPE_New_sum
# client_cash_NAME_CONTRACT_STATUS_Demand_sum_min
# previous_NAME_GOODS_CATEGORY_Fitness_mean
# previous_AMT_CREDIT_min
# client_credit_AMT_DRAWINGS_ATM_CURRENT_sum_sum
# previous_NAME_CASH_LOAN_PURPOSE_Weddinggiftholiday_sum
# previous_NAME_PAYMENT_TYPE_Cashthroughthebank_mean
# previous_NAME_GOODS_CATEGORY_Furniture_mean
# previous_HOUR_APPR_PROCESS_START_mean
# previous_NAME_GOODS_CATEGORY_PhotoCinemaEquipment_sum
# previous_NAME_CASH_LOAN_PURPOSE_Purchaseofelectronicequipment_sum
# client_cash_NAME_CONTRACT_STATUS_Completed_mean_mean
# previous_NAME_PAYMENT_TYPE_Cashlessfromtheaccountoftheemployer_sum
# previous_PRODUCT_COMBINATION_POSmobilewithinterest_sum
# client_installments_AMT_INSTALMENT_sum_sum
# previous_PRODUCT_COMBINATION_POSindustrywithoutinterest_sum
# previous_NAME_CASH_LOAN_PURPOSE_Everydayexpenses_sum
# previous_NAME_CLIENT_TYPE_XNA_sum
# previous_NAME_CLIENT_TYPE_Refreshed_sum
# previous_NAME_YIELD_GROUP_low_action_mean
# previous_NAME_CONTRACT_TYPE_Cashloans_mean
# previous_WEEKDAY_APPR_PROCESS_START_TUESDAY_mean
# client_installments_NUM_INSTALMENT_VERSION_min_min
# previous_RATE_DOWN_PAYMENT_max
# previous_NAME_CASH_LOAN_PURPOSE_Moneyforathirdperson_mean
# previous_CNT_PAYMENT_mean
# client_installments_NUM_INSTALMENT_VERSION_sum_sum
# previous_NAME_GOODS_CATEGORY_Computers_sum
# client_installments_NUM_INSTALMENT_VERSION_max_sum
# previous_NAME_TYPE_SUITE_Children_mean
# previous_NAME_SELLER_INDUSTRY_Construction_sum
# client_credit_AMT_PAYMENT_TOTAL_CURRENT_min_sum
# previous_NAME_CASH_LOAN_PURPOSE_Urgentneeds_sum
# previous_DAYS_FIRST_DRAWING_mean
# client_cash_NAME_CONTRACT_STATUS_Canceled_mean_max
# previous_NAME_GOODS_CATEGORY_PhotoCinemaEquipment_mean
# previous_NAME_CASH_LOAN_PURPOSE_Moneyforathirdperson_sum
# client_installments_DAYS_INSTALMENT_sum_max
# previous_NAME_GOODS_CATEGORY_OfficeAppliances_mean
# previous_NAME_CASH_LOAN_PURPOSE_Journey_mean
# client_credit_AMT_CREDIT_LIMIT_ACTUAL_max_sum
# previous_CHANNEL_TYPE_APCashloan_sum
# previous_NAME_GOODS_CATEGORY_Tourism_mean
# previous_NAME_CONTRACT_TYPE_XNA_mean
# previous_AMT_DOWN_PAYMENT_mean
# previous_NAME_GOODS_CATEGORY_Furniture_sum
# previous_CODE_REJECT_REASON_SCOFR_sum
# previous_NAME_YIELD_GROUP_low_normal_sum
# client_cash_MONTHS_BALANCE_sum_mean
# previous_NAME_GOODS_CATEGORY_Homewares_mean
# previous_NAME_SELLER_INDUSTRY_Tourism_mean
# previous_PRODUCT_COMBINATION_POSindustrywithinterest_sum
# previous_NAME_YIELD_GROUP_low_action_sum
# client_cash_CNT_INSTALMENT_min_mean
# previous_CODE_REJECT_REASON_HC_sum
# previous_NAME_YIELD_GROUP_low_normal_mean
# client_cash_NAME_CONTRACT_STATUS_Signed_sum_sum
# previous_PRODUCT_COMBINATION_CashStreetlow_sum
# previous_NAME_PAYMENT_TYPE_Noncashfromyouraccount_mean
# previous_NAME_CASH_LOAN_PURPOSE_Gasificationwatersupply_mean
# previous_NAME_CASH_LOAN_PURPOSE_Buyingausedcar_sum
# client_credit_SK_DPD_min_sum
# previous_NAME_PAYMENT_TYPE_Cashlessfromtheaccountoftheemployer_mean
# previous_NAME_CONTRACT_TYPE_Revolvingloans_sum
# previous_NAME_CASH_LOAN_PURPOSE_Carrepairs_mean
# previous_RATE_DOWN_PAYMENT_min
# previous_CNT_PAYMENT_sum
# client_cash_NAME_CONTRACT_STATUS_Returnedtothestore_sum_mean
# client_installments_AMT_PAYMENT_max_min
# previous_NAME_YIELD_GROUP_high_sum
# client_cash_NAME_CONTRACT_STATUS_Returnedtothestore_mean_max
# previous_FLAG_LAST_APPL_PER_CONTRACT_N_sum
# previous_NAME_CASH_LOAN_PURPOSE_Repairs_sum
# previous_CHANNEL_TYPE_Channelofcorporatesales_mean
# previous_NAME_GOODS_CATEGORY_Vehicles_mean
# previous_NAME_CONTRACT_STATUS_Approved_mean
# client_cash_NAME_CONTRACT_STATUS_Returnedtothestore_mean_mean
# client_cash_NAME_CONTRACT_STATUS_Approved_sum_mean
# previous_WEEKDAY_APPR_PROCESS_START_FRIDAY_sum
# previous_NAME_GOODS_CATEGORY_MedicalSupplies_mean
# previous_PRODUCT_COMBINATION_CardXSell_sum
# client_cash_NAME_CONTRACT_STATUS_Returnedtothestore_mean_min
# previous_PRODUCT_COMBINATION_CardXSell_mean
# previous_NAME_GOODS_CATEGORY_Gardening_sum
# client_installments_NUM_INSTALMENT_NUMBER_min_max
# client_credit_AMT_DRAWINGS_POS_CURRENT_sum_sum
# previous_WEEKDAY_APPR_PROCESS_START_SUNDAY_sum
# client_cash_NAME_CONTRACT_STATUS_Active_mean_max
# client_cash_NAME_CONTRACT_STATUS_Canceled_sum_sum
# client_credit_AMT_PAYMENT_TOTAL_CURRENT_min_mean
# previous_NFLAG_INSURED_ON_APPROVAL_sum
# previous_NAME_CASH_LOAN_PURPOSE_Journey_sum
# previous_NAME_CONTRACT_TYPE_XNA_sum
# previous_NAME_CASH_LOAN_PURPOSE_Buyinganewcar_sum
# previous_NAME_TYPE_SUITE_Family_sum
# previous_NAME_GOODS_CATEGORY_DirectSales_mean
# previous_NAME_GOODS_CATEGORY_Insurance_mean
# client_credit_SK_DPD_min_mean
# previous_AMT_DOWN_PAYMENT_min
# previous_NAME_CASH_LOAN_PURPOSE_Purchaseofelectronicequipment_mean
# client_credit_CNT_DRAWINGS_POS_CURRENT_min_sum
# previous_NAME_GOODS_CATEGORY_Computers_mean
# client_credit_AMT_DRAWINGS_CURRENT_min_sum
# client_installments_NUM_INSTALMENT_VERSION_max_min
# previous_PRODUCT_COMBINATION_POSmobilewithoutinterest_mean
# client_cash_NAME_CONTRACT_STATUS_Approved_sum_min
# previous_CHANNEL_TYPE_RegionalLocal_sum
# client_cash_NAME_CONTRACT_STATUS_Signed_sum_mean
# client_cash_NAME_CONTRACT_STATUS_Signed_sum_min
# previous_CHANNEL_TYPE_Countrywide_mean
# previous_NAME_GOODS_CATEGORY_ConsumerElectronics_mean
# client_cash_CNT_INSTALMENT_FUTURE_min_min
# previous_NAME_SELLER_INDUSTRY_Furniture_sum
# previous_NAME_GOODS_CATEGORY_SportandLeisure_sum
# previous_NAME_YIELD_GROUP_XNA_mean
# previous_WEEKDAY_APPR_PROCESS_START_SUNDAY_mean
# previous_NAME_SELLER_INDUSTRY_Connectivity_sum
# previous_NAME_CASH_LOAN_PURPOSE_Carrepairs_sum
# previous_NAME_TYPE_SUITE_Other_B_sum
# previous_NAME_TYPE_SUITE_Spousepartner_mean
# client_installments_AMT_PAYMENT_min_sum
# previous_NAME_TYPE_SUITE_Groupofpeople_sum
# previous_CODE_REJECT_REASON_SCO_mean
# previous_NAME_GOODS_CATEGORY_AudioVideo_sum
# previous_CODE_REJECT_REASON_HC_mean
# previous_NAME_GOODS_CATEGORY_Mobile_mean
# previous_WEEKDAY_APPR_PROCESS_START_MONDAY_sum
# previous_NAME_GOODS_CATEGORY_Other_sum
# client_credit_AMT_DRAWINGS_OTHER_CURRENT_max_sum
# previous_NAME_CASH_LOAN_PURPOSE_Buildingahouseoranannex_mean
# previous_NAME_PRODUCT_TYPE_XNA_mean
# previous_NAME_GOODS_CATEGORY_Insurance_sum
# previous_NAME_GOODS_CATEGORY_AutoAccessories_sum
# previous_NAME_GOODS_CATEGORY_SportandLeisure_mean
# previous_PRODUCT_COMBINATION_POSindustrywithinterest_mean
# client_cash_NAME_CONTRACT_STATUS_Returnedtothestore_sum_sum
# previous_NAME_PORTFOLIO_Cards_sum
# previous_DAYS_FIRST_DUE_mean
# previous_NAME_GOODS_CATEGORY_ConsumerElectronics_sum
# previous_NAME_GOODS_CATEGORY_DirectSales_sum
# previous_NAME_CASH_LOAN_PURPOSE_Buyingahome_mean
# previous_NAME_SELLER_INDUSTRY_Connectivity_mean
# previous_NAME_CASH_LOAN_PURPOSE_Buyinganewcar_mean
# previous_PRODUCT_COMBINATION_CashStreethigh_mean
# client_cash_NAME_CONTRACT_STATUS_Approved_mean_mean
# client_cash_NAME_CONTRACT_STATUS_Signed_mean_max
# previous_CNT_PAYMENT_min
# NAME_CONTRACT_TYPE_Cashloans
# CODE_GENDER_F
# FLAG_OWN_CAR_N
# FLAG_OWN_REALTY_N
# NAME_TYPE_SUITE_Children
# NAME_TYPE_SUITE_Family
# NAME_TYPE_SUITE_Groupofpeople
# NAME_TYPE_SUITE_Other_A
# NAME_TYPE_SUITE_Other_B
# NAME_TYPE_SUITE_Spousepartner
# NAME_TYPE_SUITE_Unaccompanied
# NAME_INCOME_TYPE_Businessman
# NAME_INCOME_TYPE_Commercialassociate
# NAME_INCOME_TYPE_Stateservant
# NAME_INCOME_TYPE_Student
# NAME_INCOME_TYPE_Unemployed
# NAME_INCOME_TYPE_Working
# NAME_EDUCATION_TYPE_Academicdegree
# NAME_EDUCATION_TYPE_Highereducation
# NAME_EDUCATION_TYPE_Incompletehigher
# NAME_EDUCATION_TYPE_Lowersecondary
# NAME_EDUCATION_TYPE_Secondarysecondaryspecial
# NAME_FAMILY_STATUS_Civilmarriage
# NAME_FAMILY_STATUS_Married
# NAME_FAMILY_STATUS_Separated
# NAME_FAMILY_STATUS_Singlenotmarried
# NAME_FAMILY_STATUS_Widow
# NAME_HOUSING_TYPE_Coopapartment
# NAME_HOUSING_TYPE_Houseapartment
# NAME_HOUSING_TYPE_Municipalapartment
# NAME_HOUSING_TYPE_Officeapartment
# NAME_HOUSING_TYPE_Rentedapartment
# NAME_HOUSING_TYPE_Withparents
# OCCUPATION_TYPE_Accountants
# OCCUPATION_TYPE_Cleaningstaff
# OCCUPATION_TYPE_Cookingstaff
# OCCUPATION_TYPE_Corestaff
# OCCUPATION_TYPE_Drivers
# OCCUPATION_TYPE_HRstaff
# OCCUPATION_TYPE_Highskilltechstaff
# OCCUPATION_TYPE_ITstaff
# OCCUPATION_TYPE_Laborers
# OCCUPATION_TYPE_LowskillLaborers
# OCCUPATION_TYPE_Managers
# OCCUPATION_TYPE_Medicinestaff
# OCCUPATION_TYPE_Privateservicestaff
# OCCUPATION_TYPE_Realtyagents
# OCCUPATION_TYPE_Salesstaff
# OCCUPATION_TYPE_Secretaries
# OCCUPATION_TYPE_Securitystaff
# OCCUPATION_TYPE_Waitersbarmenstaff
# WEEKDAY_APPR_PROCESS_START_FRIDAY
# WEEKDAY_APPR_PROCESS_START_MONDAY
# WEEKDAY_APPR_PROCESS_START_SATURDAY
# WEEKDAY_APPR_PROCESS_START_SUNDAY
# WEEKDAY_APPR_PROCESS_START_THURSDAY
# WEEKDAY_APPR_PROCESS_START_TUESDAY
# WEEKDAY_APPR_PROCESS_START_WEDNESDAY
# ORGANIZATION_TYPE_Advertising
# ORGANIZATION_TYPE_Agriculture
# ORGANIZATION_TYPE_Bank
# ORGANIZATION_TYPE_BusinessEntityType1
# ORGANIZATION_TYPE_BusinessEntityType2
# ORGANIZATION_TYPE_BusinessEntityType3
# ORGANIZATION_TYPE_Cleaning
# ORGANIZATION_TYPE_Construction
# ORGANIZATION_TYPE_Culture
# ORGANIZATION_TYPE_Electricity
# ORGANIZATION_TYPE_Emergency
# ORGANIZATION_TYPE_Government
# ORGANIZATION_TYPE_Hotel
# ORGANIZATION_TYPE_Housing
# ORGANIZATION_TYPE_Industrytype1
# ORGANIZATION_TYPE_Industrytype10
# ORGANIZATION_TYPE_Industrytype11
# ORGANIZATION_TYPE_Industrytype12
# ORGANIZATION_TYPE_Industrytype13
# ORGANIZATION_TYPE_Industrytype2
# ORGANIZATION_TYPE_Industrytype3
# ORGANIZATION_TYPE_Industrytype4
# ORGANIZATION_TYPE_Industrytype5
# ORGANIZATION_TYPE_Industrytype6
# ORGANIZATION_TYPE_Industrytype7
# ORGANIZATION_TYPE_Industrytype8
# ORGANIZATION_TYPE_Industrytype9
# ORGANIZATION_TYPE_Insurance
# ORGANIZATION_TYPE_Kindergarten
# ORGANIZATION_TYPE_LegalServices
# ORGANIZATION_TYPE_Medicine
# ORGANIZATION_TYPE_Military
# ORGANIZATION_TYPE_Mobile
# ORGANIZATION_TYPE_Other
# ORGANIZATION_TYPE_Police
# ORGANIZATION_TYPE_Postal
# ORGANIZATION_TYPE_Realtor
# ORGANIZATION_TYPE_Religion
# ORGANIZATION_TYPE_Restaurant
# ORGANIZATION_TYPE_School
# ORGANIZATION_TYPE_Security
# ORGANIZATION_TYPE_SecurityMinistries
# ORGANIZATION_TYPE_Selfemployed
# ORGANIZATION_TYPE_Services
# ORGANIZATION_TYPE_Telecom
# ORGANIZATION_TYPE_Tradetype1
# ORGANIZATION_TYPE_Tradetype2
# ORGANIZATION_TYPE_Tradetype3
# ORGANIZATION_TYPE_Tradetype4
# ORGANIZATION_TYPE_Tradetype5
# ORGANIZATION_TYPE_Tradetype6
# ORGANIZATION_TYPE_Tradetype7
# ORGANIZATION_TYPE_Transporttype1
# ORGANIZATION_TYPE_Transporttype2
# ORGANIZATION_TYPE_Transporttype3
# ORGANIZATION_TYPE_Transporttype4
# ORGANIZATION_TYPE_University
# FONDKAPREMONT_MODE_notspecified
# FONDKAPREMONT_MODE_orgspecaccount
# FONDKAPREMONT_MODE_regoperaccount
# FONDKAPREMONT_MODE_regoperspecaccount
# HOUSETYPE_MODE_blockofflats
# HOUSETYPE_MODE_specifichousing
# HOUSETYPE_MODE_terracedhouse
# WALLSMATERIAL_MODE_Block
# WALLSMATERIAL_MODE_Mixed
# WALLSMATERIAL_MODE_Monolithic
# WALLSMATERIAL_MODE_Others
# WALLSMATERIAL_MODE_Panel
# WALLSMATERIAL_MODE_Stonebrick
# WALLSMATERIAL_MODE_Wooden
# EMERGENCYSTATE_MODE_Yes

# %%
# Fit the model twice to avoid overfitting
for i in range(2):
    
    # Split into training and validation set
    train_features, valid_features, train_y, valid_y = train_test_split(train, train_labels, test_size = 0.25, random_state = i)
    
    # Train using early stopping
    model.fit(train_features, train_y, early_stopping_rounds=100, eval_set = [(valid_features, valid_y)], 
              eval_metric = 'auc', verbose = 200)
    
    # Record the feature importances
    feature_importances += model.feature_importances_
# Out:
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's auc: 0.780653	valid_0's binary_logloss: 0.508546
# Early stopping, best iteration is:
# [129]	valid_0's auc: 0.781619	valid_0's binary_logloss: 0.527389
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's auc: 0.78425	valid_0's binary_logloss: 0.507989
# Early stopping, best iteration is:
# [127]	valid_0's auc: 0.784828	valid_0's binary_logloss: 0.527481

# %%
# Make sure to average feature importances! 
feature_importances = feature_importances / 2
feature_importances = pd.DataFrame({'feature': list(train.columns), 'importance': feature_importances}).sort_values('importance', ascending = False)

feature_importances.head()
# Out:
#                                      feature  importance
# 24                              EXT_SOURCE_1       153.5
# 25                              EXT_SOURCE_2       116.0
# 26                              EXT_SOURCE_3       115.0
# 5                                 DAYS_BIRTH        84.0
# 678  client_installments_AMT_PAYMENT_min_sum        78.0

# %%
# Find the features with zero importance
zero_features = list(feature_importances[feature_importances['importance'] == 0.0]['feature'])
print('There are %d features with 0.0 importance' % len(zero_features))
feature_importances.tail()
# Out:
# There are 311 features with 0.0 importance
#                                                feature  importance
# 440  previous_NAME_CASH_LOAN_PURPOSE_Gasificationwa...         0.0
# 437  previous_PRODUCT_COMBINATION_POSotherswithouti...         0.0
# 433  previous_NAME_CASH_LOAN_PURPOSE_Buyingaholiday...         0.0
# 432  previous_PRODUCT_COMBINATION_POShouseholdwithi...         0.0
# 834                            EMERGENCYSTATE_MODE_Yes         0.0

# %% [markdown]
# We see that one of our features made it into the top 5 most important! That's a good sign for all of our hard work making the features. It also looks like many of the features we made have literally 0 importance. For the gradient boosting machine, features with 0 importance are not used at all to make any splits. Therefore, we can remove these features from the model with no effect on performance (except for faster training).

# %%
def plot_feature_importances(df, threshold = 0.9):
    """
    Plots 15 most important features and the cumulative importance of features.
    Prints the number of features needed to reach threshold cumulative importance.
    
    Parameters
    --------
    df : dataframe
        Dataframe of feature importances. Columns must be feature and importance
    threshold : float, default = 0.9
        Threshold for prining information about cumulative importances
        
    Return
    --------
    df : dataframe
        Dataframe ordered by feature importances with a normalized column (sums to 1)
        and a cumulative importance column
    
    """
    
    plt.rcParams['font.size'] = 18
    
    # Sort features according to importance
    df = df.sort_values('importance', ascending = False).reset_index()
    
    # Normalize the feature importances to add up to one
    df['importance_normalized'] = df['importance'] / df['importance'].sum()
    df['cumulative_importance'] = np.cumsum(df['importance_normalized'])

    # Make a horizontal bar chart of feature importances
    plt.figure(figsize = (10, 6))
    ax = plt.subplot()
    
    # Need to reverse the index to plot most important on top
    ax.barh(list(reversed(list(df.index[:15]))), 
            df['importance_normalized'].head(15), 
            align = 'center', edgecolor = 'k')
    
    # Set the yticks and labels
    ax.set_yticks(list(reversed(list(df.index[:15]))))
    ax.set_yticklabels(df['feature'].head(15))
    
    # Plot labeling
    plt.xlabel('Normalized Importance'); plt.title('Feature Importances')
    plt.show()
    
    # Cumulative importance plot
    plt.figure(figsize = (8, 6))
    plt.plot(list(range(len(df))), df['cumulative_importance'], 'r-')
    plt.xlabel('Number of Features'); plt.ylabel('Cumulative Importance'); 
    plt.title('Cumulative Feature Importance');
    plt.show();
    
    importance_index = np.min(np.where(df['cumulative_importance'] > threshold))
    print('%d features required for %0.2f of cumulative importance' % (importance_index + 1, threshold))
    
    return df

# %%
norm_feature_importances = plot_feature_importances(feature_importances)
# Out:
# 264 features required for 0.90 of cumulative importance

# %% [markdown]
# Let's remove the features that have zero importance.

# %%
train = train.drop(columns = zero_features)
test = test.drop(columns = zero_features)

print('Training shape: ', train.shape)
print('Testing shape: ', test.shape)
# Out:
# Training shape:  (307511, 524)
# Testing shape:  (48744, 524)

# %% [markdown]
# At this point, we can re-run the model to see if it identifies any more features with zero importance. In a way, we are implementing our own form of recursive feature elimination. Since we are repeating work, we should probably put the zero feature importance identification code in a function.

# %%
def identify_zero_importance_features(train, train_labels, iterations = 2):
    """
    Identify zero importance features in a training dataset based on the 
    feature importances from a gradient boosting model. 
    
    Parameters
    --------
    train : dataframe
        Training features
        
    train_labels : np.array
        Labels for training data
        
    iterations : integer, default = 2
        Number of cross validation splits to use for determining feature importances
    """
    
    # Initialize an empty array to hold feature importances
    feature_importances = np.zeros(train.shape[1])

    # Create the model with several hyperparameters
    model = lgb.LGBMClassifier(objective='binary', boosting_type = 'goss', n_estimators = 10000, class_weight = 'balanced')
    
    # Fit the model multiple times to avoid overfitting
    for i in range(iterations):

        # Split into training and validation set
        train_features, valid_features, train_y, valid_y = train_test_split(train, train_labels, test_size = 0.25, random_state = i)

        # Train using early stopping
        model.fit(train_features, train_y, early_stopping_rounds=100, eval_set = [(valid_features, valid_y)], 
                  eval_metric = 'auc', verbose = 200)

        # Record the feature importances
        feature_importances += model.feature_importances_ / iterations
    
    feature_importances = pd.DataFrame({'feature': list(train.columns), 'importance': feature_importances}).sort_values('importance', ascending = False)
    
    # Find the features with zero importance
    zero_features = list(feature_importances[feature_importances['importance'] == 0.0]['feature'])
    print('\nThere are %d features with 0.0 importance' % len(zero_features))
    
    return zero_features, feature_importances

# %%
second_round_zero_features, feature_importances = identify_zero_importance_features(train, train_labels)
# Out:
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's auc: 0.780412	valid_0's binary_logloss: 0.508677
# Early stopping, best iteration is:
# [139]	valid_0's auc: 0.78172	valid_0's binary_logloss: 0.524605
# Training until validation scores don't improve for 100 rounds
# [200]	valid_0's auc: 0.784176	valid_0's binary_logloss: 0.508085
# Early stopping, best iteration is:
# [151]	valid_0's auc: 0.784992	valid_0's binary_logloss: 0.520569
#
# There are 0 features with 0.0 importance

# %% [markdown]
# There are now no 0 importance features left (I guess we should have expected this). If we want to remove more features, we will have to start with features that have a non-zero importance. One way we could do this is by retaining enough features to account for a threshold percentage of importance, such as 95%. At this point, let's keep enough features to account for 95% of the importance. Again, this is an arbitrary decision!

# %%
norm_feature_importances = plot_feature_importances(feature_importances, threshold = 0.95)
# Out:
# 340 features required for 0.95 of cumulative importance

# %% [markdown]
# We can keep only the features needed for 95% importance. This step seems to me to have the greatest chance of harming the model's learning ability, so rather than changing the original dataset, we will make smaller copies. Then, we can test both versions of the data to see if the extra feature removal step is worthwhile.

# %%
# Threshold for cumulative importance
threshold = 0.95

# Extract the features to keep
features_to_keep = list(norm_feature_importances[norm_feature_importances['cumulative_importance'] < threshold]['feature'])

# Create new datasets with smaller features
train_small = train[features_to_keep]
test_small = test[features_to_keep]

# %%
train.shape
# Out:
# (307511, 524)

# %%
train_small.shape
# Out:
# (307511, 338)

# %%
train_small['TARGET'] = train_labels
train_small['SK_ID_CURR'] = train_ids
test_small['SK_ID_CURR'] = test_ids

train_small.to_feather('../../output/m_train_small.ft')
test_small.to_feather('../../output/m_test_small.ft')
